# %%
from dotenv import load_dotenv
import os

load_dotenv()

api_key = os.getenv("OPENAI_API_KEY")
if api_key:
    print("✅ 成功讀取 OPENAI_API_KEY")
else:
    print("❌ 沒有讀取到 OPENAI_API_KEY，請檢查 .env 檔")

from langchain.chat_models import ChatOpenAI

llm = ChatOpenAI(model_name="gpt-4o", temperature=1)
response = llm.invoke("hello")
print("✅ LLM 測試回應：", response.content)
# Out:
# ✅ 成功讀取 OPENAI_API_KEY
# C:\Users\chen\AppData\Local\Temp\ipykernel_34412\2719606916.py:14: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import ChatOpenAI``.
#   llm = ChatOpenAI(model_name="gpt-4o", temperature=1)
# ✅ LLM 測試回應： Hello! How can I assist you today?

# %%
from langchain_community.document_loaders import DirectoryLoader, PyPDFLoader, PyPDFDirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_openai import AzureChatOpenAI, AzureOpenAIEmbeddings
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain.vectorstores import Chroma
# from qdrant_client import QdrantClient
# from langchain_qdrant import QdrantVectorStore
from langchain_core.runnables.history import RunnableWithMessageHistory
from typing import Dict
from langchain.schema.runnable import RunnableMap, RunnableLambda
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_core.chat_history import InMemoryChatMessageHistory

# 配置 LLM 模型
generator_llm = ChatOpenAI(
    model_name="gpt-4o",   # 或 "gpt-4", "gpt-3.5-turbo"
    temperature=0.3,       # 控制回答穩定性。推薦值：0~0.3（任務導向），0.7~1（創意任務）
    max_tokens=8192,       # 控制回應長度。推薦根據任務調整，如摘要可短，技術問答可設長
    # top_p=1,               # Nucleus sampling，與 temperature 二選一，預設不動
    frequency_penalty=0.8,   # 減少重複字詞（0~2）
    presence_penalty=0.2,    # 鼓勵新話題（0~2）
)

# 配置嵌入模型
embedding_model = OpenAIEmbeddings(
    model="text-embedding-3-small",
    # chunk_size=64  # 每次送 16 段去嵌入
)

# %%
import os
import glob
import logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)
# ✅ 改進的PDF載入函數，能夠處理損壞的PDF
def safe_load_pdfs(pdf_dir="../GPTsearch", use_directory_loader=True):
    """
    安全地載入PDF文件，跳過損壞的文件
    
    Args:
        pdf_dir: PDF文件目錄
        use_directory_loader: 是否使用DirectoryLoader (True) 或 PyPDFDirectoryLoader (False)
        
    Returns:
        loaded_documents: 成功載入的文件列表
    """
    loaded_documents = []
    failed_files = []
    
    if use_directory_loader:
        # 使用DirectoryLoader時的處理方式
        pdf_files = glob.glob(os.path.join(pdf_dir, "**", "*.pdf"), recursive=True)
        logger.info(f"找到 {len(pdf_files)} 個PDF文件")
        
        for pdf_file in pdf_files:
            try:
                logger.info(f"嘗試載入: {pdf_file}")
                loader = PyPDFLoader(pdf_file)
                docs = loader.load()
                loaded_documents.extend(docs)
                logger.info(f"成功載入: {pdf_file}, 共 {len(docs)} 頁")
            except Exception as e:
                logger.error(f"無法載入 {pdf_file}: {str(e)}")
                failed_files.append(pdf_file)
    else:
        # 使用PyPDFDirectoryLoader的替代方案
        try:
            loader = PyPDFDirectoryLoader(pdf_dir)
            loaded_documents = loader.load()
            logger.info(f"使用PyPDFDirectoryLoader載入了 {len(loaded_documents)} 個文件")
        except Exception as e:
            logger.error(f"PyPDFDirectoryLoader失敗: {str(e)}")
            # 如果整體載入失敗，改為逐個文件嘗試
            return safe_load_pdfs(pdf_dir, use_directory_loader=True)
    
    if failed_files:
        logger.warning(f"有 {len(failed_files)} 個文件無法載入: {failed_files}")
    
    logger.info(f"總共成功載入 {len(loaded_documents)} 頁PDF內容")
    return loaded_documents

# %%
# 載入PDF文件
documents = safe_load_pdfs("../GPTsearch")
print(f"總共載入 {len(documents)} 篇文件")

# ✅ 分段：一份 PDF 切成多個 chunk（準備送嵌入）
splitter = RecursiveCharacterTextSplitter(
    chunk_size=800,
    chunk_overlap=200
)
splits = splitter.split_documents(documents)
print(f"總共分割成 {len(splits)} 個 chunk")

# 配置嵌入模型
embedding_model = OpenAIEmbeddings(
    model="text-embedding-3-small",
    chunk_size=64  # 每次送 16 段去嵌入
)

# ✅ 建立向量庫並保存到本地
vectorstore = Chroma.from_documents(
    documents=splits,
    embedding=embedding_model,
    persist_directory="./chroma8_db"  # 指定本地存儲位置
)

# 確保資料被寫入磁碟
vectorstore.persist()
# Out:
# 2025-04-18 21:15:21,014 - INFO - 找到 8 個PDF文件
# 2025-04-18 21:15:21,015 - INFO - 嘗試載入: ../GPTsearch\1-s2.0-S0966979519311021-main.pdf
# 2025-04-18 21:15:21,705 - INFO - 成功載入: ../GPTsearch\1-s2.0-S0966979519311021-main.pdf, 共 11 頁
# 2025-04-18 21:15:21,706 - INFO - 嘗試載入: ../GPTsearch\1-s2.0-S1003632622660862-main.pdf
# 2025-04-18 21:15:22,169 - INFO - 成功載入: ../GPTsearch\1-s2.0-S1003632622660862-main.pdf, 共 24 頁
# 2025-04-18 21:15:22,170 - INFO - 嘗試載入: ../GPTsearch\1-s2.0-S2238785422018725-main.pdf
# 2025-04-18 21:15:22,464 - INFO - 成功載入: ../GPTsearch\1-s2.0-S2238785422018725-main.pdf, 共 15 頁
# 2025-04-18 21:15:22,465 - INFO - 嘗試載入: ../GPTsearch\high-entropy-alloys-as-catalysts-for-the-co2-and-co-reduction-reactions.pdf
# 2025-04-18 21:15:22,603 - INFO - 成功載入: ../GPTsearch\high-entropy-alloys-as-catalysts-for-the-co2-and-co-reduction-reactions.pdf, 共 15 頁
# 2025-04-18 21:15:22,604 - INFO - 嘗試載入: ../GPTsearch\High‐entropy alloy catalysts_ From bulk to nano toward highly efficient carbon and nitrogen catalysis - Yu - 2022 - Carbon Energy - Wiley Online Library.pdf
# 2025-04-18 21:15:23,650 - INFO - 成功載入: ../GPTsearch\High‐entropy alloy catalysts_ From bulk to nano toward highly efficient carbon and nitrogen catalysis - Yu - 2022 - Carbon Energy - Wiley Online Library.pdf, 共 61 頁
# 2025-04-18 21:15:23,651 - INFO - 嘗試載入: ../GPTsearch\materials-15-04822.pdf
# 2025-04-18 21:15:24,014 - INFO - 成功載入: ../GPTsearch\materials-15-04822.pdf, 共 16 頁
# 2025-04-18 21:15:24,014 - INFO - 嘗試載入: ../GPTsearch\metals-13-00363-v2.pdf
# 2025-04-18 21:15:24,660 - INFO - 成功載入: ../GPTsearch\metals-13-00363-v2.pdf, 共 29 頁
# 2025-04-18 21:15:24,660 - INFO - 嘗試載入: ../GPTsearch\Microstructure_and_Wear_Behavior_of_CoCrFeMnNbNi_H.pdf
# 2025-04-18 21:15:24,845 - INFO - 成功載入: ../GPTsearch\Microstructure_and_Wear_Behavior_of_CoCrFeMnNbNi_H.pdf, 共 5 頁
# 2025-04-18 21:15:24,846 - INFO - 總共成功載入 176 頁PDF內容
# 總共載入 176 篇文件
# 總共分割成 1023 個 chunk
# 2025-04-18 21:15:25,527 - INFO - Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# 2025-04-18 21:15:27,928 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-04-18 21:15:29,747 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-04-18 21:15:31,333 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-04-18 21:15:33,537 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-04-18 21:15:35,616 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-04-18 21:15:37,340 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-04-18 21:15:38,666 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-04-18 21:15:39,959 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-04-18 21:15:41,449 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-04-18 21:15:42,903 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-04-18 21:15:45,292 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-04-18 21:15:47,048 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-04-18 21:15:48,849 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-04-18 21:15:50,466 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-04-18 21:15:52,715 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-04-18 21:15:54,682 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# C:\Users\chen\AppData\Local\Temp\ipykernel_7156\1650444601.py:27: LangChainDeprecationWarning: Since Chroma 0.4.x the manual persistence method is no longer supported as docs are automatically persisted.
#   vectorstore.persist()

# %%
# ✅ 如果要載入已存在的向量庫，可以使用以下代碼
loaded_vectorstore = Chroma(
    persist_directory="./chroma60_db",
    embedding_function=embedding_model
)

# 定義系統提示模板
# prompt = ChatPromptTemplate.from_messages([
# ("system", 
#      """You are a research assistant specializing in materials science and engineering, with expertise in literature summarization, property analysis, and application interpretation.
# Please help the user search for and organize information related to materials according to the following principles:

# - Your responses must be based on reliable sources or literature, and all sources should be clearly cited.
# - Do not fabricate data. If data is missing or unavailable, explicitly state “no data available” or “not mentioned in the literature.”
# - If multiple entries meet the query criteria, present them in a comparison table.
# - Use clear, objective, and academic language suitable for direct inclusion in technical reports.
# - Please format each summary using the following structure:
#     \n\n{context}"""),
#     MessagesPlaceholder(variable_name="history"),
#     ("human", "{question}")
# ])
# from langchain.prompts import ChatPromptTemplate, MessagesPlaceholder

prompt = ChatPromptTemplate.from_messages([
    ("system", 
    """You are a research assistant specializing in materials science and engineering, with expertise in literature summarization, property analysis, and application interpretation.

Your main task is to assist the user by searching, organizing, and summarizing high-entropy alloy (HEA) research according to the following principles:

- Base all responses strictly on peer-reviewed literature or credible sources, with proper citations.
- Do not fabricate any data. If data is unavailable, say “no data available” or “not mentioned in the literature.”
- When multiple relevant results are available, organize them into a comparison table.
- Use academic, objective, and concise language suitable for inclusion in technical reports or papers.
- Format your summary using the following structure:
  \n\n{context}

You may be asked to perform the following types of HEA summarization tasks. Please follow the intent behind each:

1. **By Synthesis or Processing Methods**  
   Summarize recent HEA research categorized by synthesis or processing methods (e.g., arc melting, powder metallurgy, additive manufacturing).

2. **By Major Application Categories**  
   Summarize HEA research according to major application domains (e.g., structural materials, coatings, catalysts, thermoelectrics, etc.).

3. **By Catalytic Functionality (Electrocatalysis)**  
   Summarize commonly used HEA element compositions specifically for the following catalytic reactions:  
   - Oxygen Reduction Reaction (ORR)  
   - Hydrogen Oxidation Reaction (HOR)  
   - Oxygen Evolution Reaction (OER)  
   - Hydrogen Evolution Reaction (HER)  

Be prepared to synthesize key findings, commonly used elements, and performance insights for each category."""),    
    MessagesPlaceholder(variable_name="history"),
    ("human", "{question}")
])

# 定義檢索與串接函數
def retrieve_and_concat(inputs: Dict[str, str]) -> str:
    query = inputs["question"]
    top_k = inputs.get("top_k", 5)

    # 使用動態設定的 k
    # custom_retriever = vectorstore.as_retriever(search_kwargs={"k": top_k})
    custom_retriever = loaded_vectorstore.as_retriever(search_kwargs={"k": top_k})

    docs = custom_retriever.get_relevant_documents(query)

    context = ""
    for i, doc in enumerate(docs):
        meta = doc.metadata
        context += f"[{i+1}] 來源：{meta.get('source', '未知')}，第 {meta.get('page', '?')} 頁\n"
        context += doc.page_content + "\n\n"
    return context

retriever_chain = RunnableLambda(retrieve_and_concat)

# ✅ QA Chain 組合
qa_chain = (
    RunnableMap({
        "context": retriever_chain,
        "question": lambda x: x["question"],
        "history": lambda x: [] 
    })
    | prompt
    | generator_llm
    | StrOutputParser()
)

# 定義會話歷史獲取函數
def get_session_history(session_id: str):
    return InMemoryChatMessageHistory()

# 建立帶有記憶功能的QA鏈
qa_chain_with_memory = RunnableWithMessageHistory(
    qa_chain,                        # 原本的 QA chain
    get_session_history,            # 記憶取得函式
    input_messages_key="question",  # 問題在哪個欄位
    # output_messages_key="answer",   # 回答會存在這裡
    history_messages_key="history"  # prompt 需要的 history
)

# 提問函數
def ask_with_memory(chain, question: str, session_id: str = "default", top_k: int = 5):
    query_input = {"question": question, "top_k": top_k}
    print("🧪 問題：", question)
    response = chain.invoke(query_input, config={"configurable": {"session_id": session_id}})
    print("🤖 回答：", response)
    return response

# %%
# 示例查詢
ask_with_memory(qa_chain_with_memory, "請問在目前的高熵合金應用中，哪些元素組合常見於催化劑？", session_id="chen041960-2", top_k=200)
# Out:
# 🧪 問題： 請問在目前的高熵合金應用中，哪些元素組合常見於催化劑？
# 🤖 回答： 在高熵合金（HEA）作為催化劑的應用中，常見的元素組合包括：
#
# 1. **氧還原反應 (ORR)**：
#    - 常用組合：FeCoNiCrMn、PtPdCuAgAu
#    - 這些組合通常因其多樣化的活性位點和優異的穩定性而被選擇，用於提高氧還原反應的效率。
#
# 2. **氫氧化反應 (HOR)**：
#    - 常用組合：PtRu、RhPt
#    - 這些元素因其在氫氣吸附和解離方面的優越性能而被廣泛使用。
#
# 3. **氧演化反應 (OER)**：
#    - 常用組合：IrPdPtRhRu、CoCuGaNiZn
#    - 這些高熵合金因其能夠提供多種活性位點並促進氧氣生成而受到關注。
#
# 4. **氫演化反應 (HER)**：
#    - 常用組合：NiFeCoCu、PtNiFeCoCu
#    - 此類組成以其出色的電催化性能和耐久性著稱，適合作為氫氣生成催化劑。
#
# 這些元素組合作為高熵合金催化劑的一部分，利用了不同金屬間協同效應來提升催化性能。[來源: Yeh et al., A perspective on the catalysis using the high-entropy alloys, Nano Energy, 2021]
# '在高熵合金（HEA）作為催化劑的應用中，常見的元素組合包括：\n\n1. **氧還原反應 (ORR)**：\n   - 常用組合：FeCoNiCrMn、PtPdCuAgAu\n   - 這些組合通常因其多樣化的活性位點和優異的穩定性而被選擇，用於提高氧還原反應的效率。\n\n2. **氫氧化反應 (HOR)**：\n   - 常用組合：PtRu、RhPt\n   - 這些元素因其在氫氣吸附和解離方面的優越性能而被廣泛使用。\n\n3. **氧演化反應 (OER)**：\n   - 常用組合：IrPdPtRhRu、CoCuGaNiZn\n   - 這些高熵合金因其能夠提供多種活性位點並促進氧氣生成而受到關注。\n\n4. **氫演化反應 (HER)**：\n   - 常用組合：NiFeCoCu、PtNiFeCoCu\n   - 此類組成以其出色的電催化性能和耐久性著稱，適合作為氫氣生成催化劑。\n\n這些元素組合作為高熵合金催化劑的一部分，利用了不同金屬間協同效應來提升催化性能。[來源: Yeh et al., A perspective on the catalysis using the high-entropy alloys, Nano Energy, 2021]'

# %%
ask_with_memory(qa_chain_with_memory, "哪一組合金性能最好？", session_id="chen041960-2", top_k=50)
# Out:
# 🧪 問題： 哪一組合金性能最好？
# 🤖 回答： 要比較高熵合金（HEA）的性能，首先需要明確所關心的性能指標，例如機械強度、耐磨性、抗腐蝕性等。以下是一些常見的高熵合金及其相關性能數據：
#
# | 合金組成 | 屈服強度 (MPa) | 極限抗拉強度 (UTS, MPa) | 延伸率 (%) | 硬度 (HV) |
# |---------|-----------------|--------------------------|------------|-----------|
# | AlCoCrCuFeNi [2] | 不詳 | 不詳 | 不詳 | 120-650（隨Al含量增加） |
# | HfNbTaTiZr [5]  | 不詳  | 不詳   | 不詳  | 高硬度和良好的耐磨性 |
# | Al0.5CrFe1.5MnNi0.5 [30]  | 高於高速鋼的軟化阻力和良好的耐磨性 |
#
# 根據不同文獻中的數據，可以看到不同合金在特定應用或條件下表現出優異的性能。例如，AlCoCrCuFeNi 隨著鋁含量增加，其硬度顯著提高，這使得它在結構和工具行業中具有潛力[2]。而HfNbTaTiZr則因其高硬度和良好的耐磨性被認為適合極端環境[5]。
#
# 具體哪一種合金性能最好取決於應用需求。如果您能提供更詳細的需求，我可以幫助進一步篩選或比較。
# '要比較高熵合金（HEA）的性能，首先需要明確所關心的性能指標，例如機械強度、耐磨性、抗腐蝕性等。以下是一些常見的高熵合金及其相關性能數據：\n\n| 合金組成 | 屈服強度 (MPa) | 極限抗拉強度 (UTS, MPa) | 延伸率 (%) | 硬度 (HV) |\n|---------|-----------------|--------------------------|------------|-----------|\n| AlCoCrCuFeNi [2] | 不詳 | 不詳 | 不詳 | 120-650（隨Al含量增加） |\n| HfNbTaTiZr [5]  | 不詳  | 不詳   | 不詳  | 高硬度和良好的耐磨性 |\n| Al0.5CrFe1.5MnNi0.5 [30]  | 高於高速鋼的軟化阻力和良好的耐磨性 |\n\n根據不同文獻中的數據，可以看到不同合金在特定應用或條件下表現出優異的性能。例如，AlCoCrCuFeNi 隨著鋁含量增加，其硬度顯著提高，這使得它在結構和工具行業中具有潛力[2]。而HfNbTaTiZr則因其高硬度和良好的耐磨性被認為適合極端環境[5]。\n\n具體哪一種合金性能最好取決於應用需求。如果您能提供更詳細的需求，我可以幫助進一步篩選或比較。'

# %%
from langchain_community.document_loaders import DirectoryLoader, PyPDFLoader, PyPDFDirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_openai import AzureChatOpenAI, AzureOpenAIEmbeddings
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain.vectorstores import Chroma
# from qdrant_client import QdrantClient
# from langchain_qdrant import QdrantVectorStore
from langchain_core.runnables.history import RunnableWithMessageHistory
from typing import Dict, List, Tuple
from langchain.schema.runnable import RunnableMap, RunnableLambda
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_core.chat_history import InMemoryChatMessageHistory
from langchain.schema.document import Document
import os
import time
from datetime import datetime
import pandas as pd

# 配置 LLM 模型
generator_llm = ChatOpenAI(
    model_name="gpt-4o",   # 或 "gpt-4", "gpt-3.5-turbo"
    temperature=0.3,       # 控制回答穩定性。推薦值：0~0.3（任務導向），0.7~1（創意任務）
    max_tokens=8192,       # 控制回應長度。推薦根據任務調整，如摘要可短，技術問答可設長
    # top_p=1,               # Nucleus sampling，與 temperature 二選一，預設不動
    frequency_penalty=0.8,   # 減少重複字詞（0~2）
    presence_penalty=0.2,    # 鼓勵新話題（0~2）
)

# 配置嵌入模型
embedding_model = OpenAIEmbeddings(
    model="text-embedding-3-small",
    chunk_size=64  # 每次送 64 段去嵌入
)

# ✅ 如果要載入已存在的向量庫，可以使用以下代碼
vectorstore = Chroma(
    persist_directory="./chroma_db",
    embedding_function=embedding_model
)

# 獲取向量庫的總文檔數量
total_documents = vectorstore._collection.count()
print(f"向量庫中共有 {total_documents} 個文檔片段")

# 定義系統提示模板
prompt = ChatPromptTemplate.from_messages([
    ("system", 
     """You are a research assistant specializing in materials science and engineering, with expertise in literature summarization, property analysis, and application interpretation.
Please help the user search for and organize information related to materials according to the following principles:

- Your responses must be based on reliable sources or literature, and all sources should be clearly cited.
- Do not fabricate data. If data is missing or unavailable, explicitly state "no data available" or "not mentioned in the literature."
- If multiple entries meet the query criteria, present them in a comparison table.
- Use clear, objective, and academic language suitable for direct inclusion in technical reports.
- Please format each summary using the following structure:
    \n\n{context}"""),
    MessagesPlaceholder(variable_name="history"),
    ("human", "{question}")
])

# 創建檢索結果的詳細資訊結構
class RetrievalInfo:
    def __init__(self):
        self.total_docs_retrieved = 0
        self.unique_sources = set()
        self.retrieval_time = 0
        self.doc_details = []
        self.similarity_scores = []
    
    def add_document(self, doc: Document, score: float = None):
        self.total_docs_retrieved += 1
        source = doc.metadata.get('source', '未知')
        self.unique_sources.add(source)
        
        # 添加文檔詳細信息
        self.doc_details.append({
            'source': source,
            'page': doc.metadata.get('page', '?'),
            'content_preview': doc.page_content[:100] + '...' if len(doc.page_content) > 100 else doc.page_content,
            'content_length': len(doc.page_content)
        })
        
        if score is not None:
            self.similarity_scores.append(score)
    
    def get_summary(self) -> str:
        summary = []
        summary.append(f"📊 檢索統計:")
        summary.append(f"- 共檢索到 {self.total_docs_retrieved} 個文檔片段")
        summary.append(f"- 來自 {len(self.unique_sources)} 個不同來源")
        summary.append(f"- 檢索耗時: {self.retrieval_time:.2f} 秒")
        
        if self.similarity_scores:
            summary.append(f"- 相似度分數範圍: {min(self.similarity_scores):.3f} - {max(self.similarity_scores):.3f}")
        
        # 創建文檔詳情表格（不使用tabulate）
        if self.doc_details:
            summary.append("\n📑 檢索文檔詳情:")
            # 添加表頭
            summary.append("索引 | 來源 | 頁碼 | 內容長度 | 內容預覽")
            summary.append("----- | ----- | ----- | ----- | -----")
            
            # 添加數據行
            for i, doc in enumerate(self.doc_details):
                summary.append(f"{i} | {doc['source']} | {doc['page']} | {doc['content_length']} | {doc['content_preview']}")
        
        return "\n".join(summary)

# 全局變數，用於存儲最近一次檢索的詳細信息
last_retrieval_info = RetrievalInfo()

# 定義檢索與串接函數，加入檢索統計功能
def retrieve_and_concat(inputs: Dict[str, str]) -> str:
    global last_retrieval_info
    
    query = inputs["question"]
    top_k = inputs.get("top_k", 5)
    
    retrieval_info = RetrievalInfo()
    
    print(f"\n⏳ 正在檢索與「{query}」相關的文檔，檢索數量: {top_k}")
    start_time = time.time()
    
    # 使用動態設定的 k
    try:
        # 首先嘗試使用帶分數的檢索方法
        custom_retriever = vectorstore.as_retriever(
            search_type="similarity_score_threshold",
            search_kwargs={"k": top_k, "score_threshold": 0.0}  # 設置閾值為0確保返回所有結果
        )
        docs_and_scores = custom_retriever.get_relevant_documents_and_scores(query)
        
        # 處理檢索結果
        context = ""
        for i, (doc, score) in enumerate(docs_and_scores):
            retrieval_info.add_document(doc, score)
            meta = doc.metadata
            context += f"[{i+1}] 來源：{meta.get('source', '未知')}，第 {meta.get('page', '?')} 頁 (相似度: {score:.3f})\n"
            context += doc.page_content + "\n\n"
    
    except (AttributeError, NotImplementedError):
        # 如果上面的方法失敗，回退到普通檢索
        print("⚠️ 帶分數檢索方法不可用，回退到普通檢索")
        custom_retriever = vectorstore.as_retriever(search_kwargs={"k": top_k})
        docs = custom_retriever.get_relevant_documents(query)
        
        # 處理檢索結果
        context = ""
        for i, doc in enumerate(docs):
            retrieval_info.add_document(doc)
            meta = doc.metadata
            context += f"[{i+1}] 來源：{meta.get('source', '未知')}，第 {meta.get('page', '?')} 頁\n"
            context += doc.page_content + "\n\n"
    
    retrieval_info.retrieval_time = time.time() - start_time
    last_retrieval_info = retrieval_info
    
    # 打印檢索統計信息
    print(retrieval_info.get_summary())
    
    return context

retriever_chain = RunnableLambda(retrieve_and_concat)

# ✅ QA Chain 組合
qa_chain = (
    RunnableMap({
        "context": retriever_chain,
        "question": lambda x: x["question"],
        "history": lambda x: [] 
    })
    | prompt
    | generator_llm
    | StrOutputParser()
)

# 定義會話歷史獲取函數
def get_session_history(session_id: str):
    return InMemoryChatMessageHistory()

# 建立帶有記憶功能的QA鏈
qa_chain_with_memory = RunnableWithMessageHistory(
    qa_chain,                        # 原本的 QA chain
    get_session_history,            # 記憶取得函式
    input_messages_key="question",  # 問題在哪個欄位
    # output_messages_key="answer",   # 回答會存在這裡
    history_messages_key="history"  # prompt 需要的 history
)

# 提問函數，添加查詢資訊記錄
def ask_with_memory(chain, question: str, session_id: str = "default", top_k: int = 5, show_retrieval_info: bool = True):
    # 記錄查詢開始時間
    start_time = time.time()
    print(f"\n===== {datetime.now().strftime('%Y-%m-%d %H:%M:%S')} =====")
    print(f"🧪 問題：{question}")
    print(f"🔍 會話ID: {session_id}, 檢索數量: {top_k}")
    
    # 執行查詢
    query_input = {"question": question, "top_k": top_k}
    response = chain.invoke(query_input, config={"configurable": {"session_id": session_id}})
    
    # 記錄總耗時
    total_time = time.time() - start_time
    
    print(f"\n🤖 回答：{response}")
    print(f"\n⏱️ 總耗時: {total_time:.2f} 秒")
    
    # 保存查詢記錄到文件
    with open(f"query_log_{session_id}.txt", "a", encoding="utf-8") as f:
        f.write(f"===== {datetime.now().strftime('%Y-%m-%d %H:%M:%S')} =====\n")
        f.write(f"問題: {question}\n")
        f.write(f"檢索數量: {top_k}\n")
        f.write(f"檢索文檔數: {last_retrieval_info.total_docs_retrieved}\n")
        f.write(f"回答: {response}\n")
        f.write(f"總耗時: {total_time:.2f} 秒\n\n")
    
    return response

# 獲取最近一次檢索的詳細信息
def get_last_retrieval_info():
    global last_retrieval_info
    return last_retrieval_info.get_summary()

# ✅ 向量庫統計功能
def get_vectorstore_stats():
    """獲取向量庫的統計信息"""
    total_docs = vectorstore._collection.count()
    
    # 嘗試獲取所有文檔的元數據
    try:
        metadata_list = vectorstore._collection.get(include=["metadatas"])["metadatas"]
        
        # 分析來源和頁數
        sources = {}
        page_counts = {}
        
        for metadata in metadata_list:
            source = metadata.get('source', '未知')
            page = metadata.get('page', '未知')
            
            if source in sources:
                sources[source] += 1
            else:
                sources[source] = 1
                
            if page in page_counts:
                page_counts[page] += 1
            else:
                page_counts[page] = 1
        
        # 生成統計報告
        stats = []
        stats.append(f"📚 向量庫統計報告:")
        stats.append(f"- 總文檔數: {total_docs}")
        stats.append(f"- 唯一來源數: {len(sources)}")
        
        # 來源分布
        stats.append("\n📂 文檔來源分布:")
        for source, count in sorted(sources.items(), key=lambda x: x[1], reverse=True):
            stats.append(f"- {source}: {count} 個片段 ({count/total_docs*100:.1f}%)")
        
        return "\n".join(stats)
        
    except Exception as e:
        return f"📚 向量庫統計報告:\n- 總文檔數: {total_docs}\n- 詳細統計獲取失敗: {str(e)}"

# 打印向量庫統計信息
print(get_vectorstore_stats())

# 示例查詢
print("\n======== 開始查詢示例 ========")
ask_with_memory(qa_chain_with_memory, "請問在目前的高熵合金應用中，哪些元素組合常見於催化劑？", session_id="chen03", top_k=100)
print("\n---- 最近一次檢索的詳細信息 ----")
print(get_last_retrieval_info())

ask_with_memory(qa_chain_with_memory, "哪一組合金性能最好？", session_id="chen03", top_k=20)
print("\n---- 最近一次檢索的詳細信息 ----")
print(get_last_retrieval_info())
# Out:
# 向量庫中共有 81427 個文檔片段
# 📚 向量庫統計報告:
# - 總文檔數: 81427
# - 唯一來源數: 1090
#
# 📂 文檔來源分布:
# - ../PDF\Zhang …等 - 2024 - Frontiers in high entropy alloys and high entropy functional materials.pdf: 1097 個片段 (1.3%)
# - ../PDF\Additive-manufacturing-of-nickel-based-superalloys--A-sta_2023_Progress-in-M.pdf: 909 個片段 (1.1%)
# - ../PDF\Cantor - 2021 - Multicomponent high-entropy Cantor alloys.pdf: 527 個片段 (0.6%)
# - ../PDF\Mishra …等 - 2021 - High entropy alloys  Tunability of deformation mechanisms through integration of compositional and.pdf: 489 個片段 (0.6%)
# - ../PDF\Li …等 - 2019 - Mechanical properties of high-entropy alloys with emphasis on face-centered cubic alloys.pdf: 357 個片段 (0.4%)
# - ../PDF\Liu …等 - 2021 - The Evolution of Intermetallic Compounds in High-Entropy Alloys From the Secondary Phase to the Mai.pdf: 321 個片段 (0.4%)
# - ../PDF\Mooraj和Chen - 2023 - A review on high-throughput development of high-entropy alloys by combinatorial methods.pdf: 284 個片段 (0.3%)
# - ../PDF\Rogachev - 2020 - Structure, Stability, and Properties of High-Entropy Alloys.pdf: 272 個片段 (0.3%)
# - ../PDF\Hua …等 - 2022 - Development and Property Tuning of Refractory High-Entropy Alloys A Review.pdf: 265 個片段 (0.3%)
# - ../PDF\Somo …等 - 2023 - Hydrogen storage behaviours of high entropy alloys A Review.pdf: 263 個片段 (0.3%)
# - ../PDF\Bataeva …等 - 2021 - Review of alloys developed using the entropy approach.pdf: 262 個片段 (0.3%)
# - ../PDF\Sathiyamoorthi和Kim - 2022 - High-entropy alloys with heterogeneous microstructure Processing and mechanical properties.pdf: 250 個片段 (0.3%)
# - ../PDF\metals-13-00363-v2.pdf: 243 個片段 (0.3%)
# - ../PDF\Wu …等 - 2024 - Review on the Tensile Properties and Strengthening Mechanisms of Additive Manufactured CoCrFeNi-Base.pdf: 236 個片段 (0.3%)
# - ../PDF\Manzoni和Glatzel - 2019 - New multiphase compositionally complex alloys driven by the high entropy alloy approach.pdf: 235 個片段 (0.3%)
# - ../PDF\Torralba …等 - 2019 - High-entropy alloys fabricated via powder metallurgy. A critical review.pdf: 235 個片段 (0.3%)
# - ../PDF\Zhou …等 - 2024 - Study on Mechanical Properties of Nanopores in CoCrFeMnNi High-Entropy Alloy Used as Drug-Eluting St.pdf: 233 個片段 (0.3%)
# - ../PDF\High‐entropy alloy catalysts_ From bulk to nano toward highly efficient carbon and nitrogen catalysis - Yu - 2022 - Carbon Energy - Wiley Online Library.pdf: 232 個片段 (0.3%)
# - ../PDF\Praveen和Kim - 2018 - High-Entropy Alloys Potential Candidates for High-Temperature Applications - An Overview.pdf: 227 個片段 (0.3%)
# - ../PDF\Garcia …等 - 2022 - Cantor-derived medium-entropy alloys bridging the gap between traditional metallic and high- entrop.pdf: 222 個片段 (0.3%)
# - ../PDF\George …等 - 2019 - High-entropy alloys.pdf: 216 個片段 (0.3%)
# - ../PDF\Pickering …等 - 2021 - High-Entropy Alloys for Advanced Nuclear Applications.pdf: 212 個片段 (0.3%)
# - ../PDF\Zhang …等 - 2022 - The effects of irradiation on CrMnFeCoNi high-entropy alloy and its derivatives.pdf: 207 個片段 (0.3%)
# - ../PDF\Abu-Odeh …等 - 2018 - Efficient exploration of the High Entropy Alloy composition-phase space.pdf: 199 個片段 (0.2%)
# - ../PDF\Lin和Yao - 2023 - Corrosion-Resistant Coating Based on High-Entropy Alloys.pdf: 197 個片段 (0.2%)
# - ../PDF\Luo …等 - 2021 - High Entropy Alloys as Filler Metals for Joining.pdf: 195 個片段 (0.2%)
# - ../PDF\Zhao …等 - 2024 - Comprehensive Study of CoCrCuNi High-Entropy Alloys Effects of Preparation, Heat Treatment, Computa.pdf: 195 個片段 (0.2%)
# - ../PDF\Chang …等 - 2020 - Phase Engineering of High-Entropy Alloys.pdf: 194 個片段 (0.2%)
# - ../PDF\Shi …等 - 2021 - Current development of body-centered cubic high-entropy alloys for nuclear applications.pdf: 194 個片段 (0.2%)
# - ../PDF\Edalati …等 - 2023 - Superfunctional high-entropy alloys and ceramics by severe plastic deformation.pdf: 193 個片段 (0.2%)
# - ../PDF\Sarswat …等 - 2020 - Design and Fabrication of New High Entropy Alloys for Evaluating Titanium Replacements in Additive M.pdf: 193 個片段 (0.2%)
# - ../PDF\Hu …等 - 2023 - An Overview on Fatigue of High-Entropy Alloys.pdf: 186 個片段 (0.2%)
# - ../PDF\Miracle …等 - 2014 - Exploration and Development of High Entropy Alloys for Structural Applications.pdf: 184 個片段 (0.2%)
# - ../PDF\Liu …等 - 2022 - Recent Progress with BCC-Structured High-Entropy Alloys.pdf: 181 個片段 (0.2%)
# - ../PDF\Constantin …等 - 2020 - Cutting Behavior of Al0.6CoCrFeNi High Entropy Alloy.pdf: 180 個片段 (0.2%)
# - ../PDF\Zhang …等 - 2022 - High-Entropy Alloys for Electrocatalysis Design, Characterization, and Applications.pdf: 177 個片段 (0.2%)
# - ../PDF\Xu …等 - 2022 - A critical review of the mechanical properties of CoCrNi-based medium-entropy alloys.pdf: 176 個片段 (0.2%)
# - ../PDF\Liu …等 - 2021 - Nanoprecipitate-Strengthened High-Entropy Alloys.pdf: 172 個片段 (0.2%)
# - ../PDF\Fu …等 - 2023 - Development of High-Entropy Shape-Memory Alloys A Review.pdf: 171 個片段 (0.2%)
# - ../PDF\Wang和Zhang - 2023 - Research and Application Progress of High-Entropy Alloys.pdf: 171 個片段 (0.2%)
# - ../PDF\Khan …等 - 2022 - Towards stacking fault energy engineering in FCC high entropy alloys.pdf: 169 個片段 (0.2%)
# - ../PDF\Gorsse …等 - 2018 - From high-entropy alloys to complex concentrated alloys.pdf: 164 個片段 (0.2%)
# - ../PDF\Manea …等 - 2023 - CoxCrFeNiTi High-Entropy Alloys Prepared via Mechanical Alloying and Spark Plasma Sintering for Magn.pdf: 163 個片段 (0.2%)
# - ../PDF\Dikonda …等 - 2025 - Oxidation Behavior of Mechanically Alloyed High-Entropy Alloys A Review.pdf: 161 個片段 (0.2%)
# - ../PDF\Akinwekomi和Akhtar - 2022 - Bibliometric Mapping of Literature on High-EntropyMulticomponent Alloys and Systematic Review of Em.pdf: 160 個片段 (0.2%)
# - ../PDF\Medina …等 - 2023 - Extending the Passive Region of CrFeNi-Based High Entropy Alloys.pdf: 158 個片段 (0.2%)
# - ../PDF\Chen …等 - 2021 - Phase transformation and strengthening mechanisms of nanostructured high-entropy alloys.pdf: 157 個片段 (0.2%)
# - ../PDF\Feng …等 - 2016 - Design of Light-Weight High-Entropy Alloys.pdf: 156 個片段 (0.2%)
# - ../PDF\Chen …等 - 2018 - Additive Manufacturing of High-Entropy Alloys A Review.pdf: 155 個片段 (0.2%)
# - ../PDF\Sivasankaran …等 - 2021 - Influence of V and Zn in FeCrCuMnTi High-Entropy Alloys on Microstructures and Uniaxial Compaction B.pdf: 153 個片段 (0.2%)
# - ../PDF\Murakami …等 - 2025 - Electroplating of Wear- and Corrosion-Resistant CrCoNi Medium-Entropy Alloys beyond Hard Chromium Co.pdf: 152 個片段 (0.2%)
# - ../PDF\Li - 2018 - Additive Manufacturing of Advanced Multi-Component Alloys Bulk Metallic Glasses and High Entropy Al.pdf: 150 個片段 (0.2%)
# - ../PDF\Shi …等 - 2023 - Corrosion-Resistant Biomedical High-Entropy Alloys A Review.pdf: 150 個片段 (0.2%)
# - ../PDF\Wang …等 - 2024 - A Review of Irradiation-Tolerant Refractory High-Entropy Alloys.pdf: 150 個片段 (0.2%)
# - ../PDF\Tsai和Yeh - 2014 - High-Entropy Alloys A Critical Review.pdf: 148 個片段 (0.2%)
# - ../PDF\Mak …等 - 2021 - A ductility criterion for bcc high entropy alloys.pdf: 147 個片段 (0.2%)
# - ../PDF\Gerard …等 - 2020 - Progress in Understanding the Origins of Excellent Corrosion Resistance in Metallic Alloys From Bin.pdf: 146 個片段 (0.2%)
# - ../PDF\Ren …等 - 2022 - Review on Preparation Technology and Properties of Refractory High Entropy Alloys.pdf: 145 個片段 (0.2%)
# - ../PDF\Tsakiropoulos - 2021 - Refractory Metal (Nb) Intermetallic Composites, High Entropy Alloys, Complex Concentrated Alloys and.pdf: 145 個片段 (0.2%)
# - ../PDF\Xie …等 - 2022 - Research Progress of Refractory High Entropy Alloys A Review.pdf: 145 個片段 (0.2%)
# - ../PDF\1-s2.0-S1003632622660862-main.pdf: 143 個片段 (0.2%)
# - ../PDF\Soni …等 - 2021 - A review on phase prediction in high entropy alloys.pdf: 143 個片段 (0.2%)
# - ../PDF\Nagase …等 - 2019 - Solidification Microstructures of the Ingots Obtained by Arc Melting and Cold Crucible Levitation Me.pdf: 142 個片段 (0.2%)
# - ../PDF\Peter …等 - 2020 - Early stage phase separation of AlCoCr0.75Cu0.5FeNi high-entropy powder at the nanoscale.pdf: 142 個片段 (0.2%)
# - ../PDF\Schön …等 - 2018 - Probing the entropy hypothesis in highly concentrated alloys.pdf: 142 個片段 (0.2%)
# - ../PDF\Shi …等 - 2017 - Corrosion-Resistant High-Entropy Alloys A Review.pdf: 141 個片段 (0.2%)
# - ../PDF\Shuang …等 - 2020 - Corrosion resistant nanostructured eutectic high entropy alloy.pdf: 141 個片段 (0.2%)
# - ../PDF\van de Walle - 2009 - Multicomponent multisublattice alloys, nonconfigurational entropy and other additions to the Alloy T.pdf: 140 個片段 (0.2%)
# - ../PDF\Roy …等 - 2022 - Modeling Oxidation of AlCoCrFeNi High-Entropy Alloy Using Stochastic Cellular Automata.pdf: 139 個片段 (0.2%)
# - ../PDF\Coury …等 - 2019 - Solid-solution strengthening in refractory high entropy alloys.pdf: 137 個片段 (0.2%)
# - ../PDF\Lin …等 - 2024 - High-Temperature Oxidation of NbTi-Bearing Refractory Medium- and High-Entropy Alloys.pdf: 136 個片段 (0.2%)
# - ../PDF\Wang …等 - 2024 - Effect of Reduced Graphene Oxide on Microwave Absorbing Properties of Al1.5Co4Fe2Cr High-Entropy All.pdf: 135 個片段 (0.2%)
# - ../PDF\Zang和Rivera-Díaz-del-Castillo - 2022 - High entropy alloy strengthening modelling.pdf: 135 個片段 (0.2%)
# - ../PDF\Li …等 - 2023 - Corrosion of Eutectic High-Entropy Alloys A Review.pdf: 134 個片段 (0.2%)
# - ../PDF\Tunes …等 - 2023 - From high-entropy alloys to high-entropy ceramics The radiation-resistant highly concentrated refra.pdf: 134 個片段 (0.2%)
# - ../PDF\Cai …等 - 2021 - Progress in Light-weight High Entropy Alloys.pdf: 133 個片段 (0.2%)
# - ../PDF\Cheng …等 - 2022 - Tribological properties of high-entropy alloys A review.pdf: 133 個片段 (0.2%)
# - ../PDF\Olejarz …等 - 2023 - Microstructure and mechanical properties of mechanically-alloyed CoCrFeNi high-entropy alloys using.pdf: 133 個片段 (0.2%)
# - ../PDF\Rozman …等 - 2022 - Long-Term Creep Behavior of a CoCrFeNi Medium-Entropy Alloy.pdf: 133 個片段 (0.2%)
# - ../PDF\Stress-controlled-fatigue-of-HfNbTaTiZr-high-entrop_2022_Journal-of-Material.pdf: 133 個片段 (0.2%)
# - ../PDF\Smekhova …等 - 2022 - Inner relaxations in equiatomic single-phase high-entropy cantor alloy.pdf: 132 個片段 (0.2%)
# - ../PDF\Sun和Ni - 2024 - Machine Learning Advances in High-Entropy Alloys A Mini-Review.pdf: 132 個片段 (0.2%)
# - ../PDF\Wong …等 - 2023 - A Review Design from Beta Titanium Alloys to Medium-Entropy Alloys for Biomedical Applications.pdf: 132 個片段 (0.2%)
# - ../PDF\Stepanov …等 - 2016 - Effect of carbon content and annealing on structure and hardness of the CoCrFeNiMn-based high entrop.pdf: 131 個片段 (0.2%)
# - ../PDF\Wei …等 - 2021 - Influencing factors and mechanism of high-temperature oxidation of high-entropy alloys A review.pdf: 130 個片段 (0.2%)
# - ../PDF\Sharma - 2021 - High Entropy Alloy Coatings and Technology.pdf: 128 個片段 (0.2%)
# - ../PDF\Manzoni …等 - 2018 - Tensile Behavior and Evolution of the Phases in the Al10Co25Cr8Fe15Ni36Ti6 Compositionally ComplexH.pdf: 127 個片段 (0.2%)
# - ../PDF\materials-15-04822.pdf: 127 個片段 (0.2%)
# - ../PDF\Sathiaraj …等 - 2020 - Texture formation in face-centered cubic high-entropy alloys.pdf: 127 個片段 (0.2%)
# - ../PDF\Ding …等 - 2024 - Composition Design Strategy for High Entropy Amorphous Alloys.pdf: 126 個片段 (0.2%)
# - ../PDF\Tian …等 - 2017 - Alloying effect on the elastic properties of refractory high-entropy alloys.pdf: 126 個片段 (0.2%)
# - ../PDF\Inverse-design-of-high-entropy-alloys-using-a-deep-inte_2024_Journal-of-Allo.pdf: 125 個片段 (0.2%)
# - ../PDF\Xia …等 - 2023 - Investigation of PbSnTeSe High-Entropy Thermoelectric Alloy A DFT Approach.pdf: 125 個片段 (0.2%)
# - ../PDF\Zhang …等 - 2024 - Towards quantifying (meta-)stability of multi-principal element alloys From configurational entropy.pdf: 125 個片段 (0.2%)
# - ../PDF\Rozman …等 - 2020 - Long-Term Creep Behavior of a CoCrFeNiMn High-Entropy Alloy.pdf: 124 個片段 (0.2%)
# - ../PDF\Torralba和Campos - 2020 - High Entropy Alloys Manufactured by Additive Manufacturing.pdf: 124 個片段 (0.2%)
# - ../PDF\Yang …等 - 2022 - Optimize the Mechanical Properties of Al0.6CoCrFeNi High-Entropy Alloys by Thermo-Mechanical Process.pdf: 124 個片段 (0.2%)
# - ../PDF\Elucidating-hierarchical-microstructures-in-high-entropy_2025_Materials-Char.pdf: 123 個片段 (0.2%)
# - ../PDF\Shojaei …等 - 2022 - Review of electrodeposition methods for the preparation of high-entropy alloys.pdf: 123 個片段 (0.2%)
# - ../PDF\Skrotzki和Chulist - 2023 - Severe Plastic Deformation of High-Entropy Alloys.pdf: 123 個片段 (0.2%)
# - ../PDF\The-role-of-intrinsic-stacking-fault-in-facilitating-the-_2022_Materials-Che.pdf: 123 個片段 (0.2%)
# - ../PDF\Tsakiropoulos - 2022 - Refractory Metal Intermetallic Composites, High-Entropy Alloys, and Complex Concentrated Alloys A R.pdf: 123 個片段 (0.2%)
# - ../PDF\Cheng …等 - 2017 - Physical metallurgy of concentrated solid solutions from low-entropy to high-entropy alloys.pdf: 122 個片段 (0.1%)
# - ../PDF\Zhang …等 - 2019 - High-Pressure Induced Phase Transitions in High-Entropy Alloys A Review.pdf: 122 個片段 (0.1%)
# - ../PDF\Varvenne …等 - 2016 - Theory of strengthening in fcc high entropy alloys.pdf: 121 個片段 (0.1%)
# - ../PDF\Thiel …等 - 2020 - Origins of strength and plasticity in the precious metal based high-entropy alloy AuCuNiPdPt.pdf: 120 個片段 (0.1%)
# - ../PDF\Tunes …等 - 2023 - Perspectives on novel refractory amorphous high-entropy alloys in extreme environments.pdf: 120 個片段 (0.1%)
# - ../PDF\Yuan …等 - 2022 - Remarkable cryogenic strengthening and toughening in nano-coherent CoCrFeNiTi0.2 high-entropy alloys.pdf: 120 個片段 (0.1%)
# - ../PDF\Zhao …等 - 2021 - Bimodality of incipient plastic strength in face-centered cubic high-entropy alloys.pdf: 120 個片段 (0.1%)
# - ../PDF\Feng …等 - 2022 - Hydrogen Embrittlement of CoCrFeMnNi High-Entropy Alloy Compared with 304 and IN718 Alloys.pdf: 119 個片段 (0.1%)
# - ../PDF\López-Ríos …等 - 2025 - New FeMoTaTiZr High-Entropy Alloy for Medical Applications.pdf: 118 個片段 (0.1%)
# - ../PDF\Mindi …等 - 2024 - Effect of Tungsten on Microstructure and Mechanical Properties of Novel NiMnCrMoWx High-Entropy Allo.pdf: 118 個片段 (0.1%)
# - ../PDF\Tsai - 2016 - Three Strategies for the Design of Advanced High-Entropy Alloys.pdf: 118 個片段 (0.1%)
# - ../PDF\Tsai …等 - 2019 - Intermetallic Phases in High-Entropy Alloys Statistical Analysis of their Prevalence and Structural.pdf: 118 個片段 (0.1%)
# - ../PDF\Xie …等 - 2023 - Wear-Resistance of High-Entropy Alloy Coatings and High-Entropy Alloy-Based Composite Coatings Prepa.pdf: 118 個片段 (0.1%)
# - ../PDF\Castro …等 - 2021 - An Overview of High-Entropy Alloys as Biomaterials.pdf: 117 個片段 (0.1%)
# - ../PDF\Hsu …等 - 2022 - Effect of Mo on the Mechanical and Corrosion Behaviors in Non-Equal Molar AlCrFeMnNi BCC High-Entrop.pdf: 117 個片段 (0.1%)
# - ../PDF\Insight-to-agglomeration-and-chemical-reactions-of-CoAl2_2021_Journal-of-All.pdf: 117 個片段 (0.1%)
# - ../PDF\Morral和Chen - 2021 - Stability of High Entropy Alloys to Spinodal Decomposition.pdf: 117 個片段 (0.1%)
# - ../PDF\Sourav …等 - 2024 - Microstructural Evolution and Mechanical Properties of Laser Beam Welded AlxCoCrFeNi High Entropy Al.pdf: 117 個片段 (0.1%)
# - ../PDF\Sun …等 - 2017 - Phase selection rule for Al-doped CrMnFeCoNi high-entropy alloys from first-principles.pdf: 117 個片段 (0.1%)
# - ../PDF\Wang …等 - 2024 - A Review of High-Temperature Toughness Improvement Strategies for Medium Entropy Alloys.pdf: 117 個片段 (0.1%)
# - ../PDF\Fan …等 - 2024 - Irradiation-Hardening Model of TiZrHfNbMo0.1 Refractory High-Entropy Alloys.pdf: 116 個片段 (0.1%)
# - ../PDF\Klaver …等 - 2018 - Brute Force Composition Scanning with a CALPHAD Database to Find Low Temperature Body Centered Cubic.pdf: 116 個片段 (0.1%)
# - ../PDF\Pérez …等 - 2023 - Control of the Microstructure in a Al5Co15Cr30Fe25Ni25 High Entropy Alloy through Thermo-Mechanical.pdf: 116 個片段 (0.1%)
# - ../PDF\Physical-metallurgy-of-concentrated-solid-sol_2017_Current-Opinion-in-Solid-.pdf: 115 個片段 (0.1%)
# - ../PDF\de Oliveira …等 - 2022 - A Review of Biomaterials Based on High-Entropy Alloys.pdf: 114 個片段 (0.1%)
# - ../PDF\Gong …等 - 2023 - Laser-cladding of high entropy alloy coatings an overview.pdf: 114 個片段 (0.1%)
# - ../PDF\Licavoli …等 - 2015 - Microstructure and Mechanical Behavior of High-Entropy Alloys.pdf: 114 個片段 (0.1%)
# - ../PDF\Recrystallized-hard-zone-and-resultant-tri-modal-microstructure-_2024_Acta-M.pdf: 114 個片段 (0.1%)
# - ../PDF\Seol …等 - 2018 - Boron doped ultrastrong and ductile high-entropy alloys.pdf: 114 個片段 (0.1%)
# - ../PDF\Rhode …等 - 2021 - Welding of high-entropy alloys and compositionally complex alloys-an overview.pdf: 113 個片段 (0.1%)
# - ../PDF\Wang …等 - 2020 - Electrical and thermal transport properties of medium-entropy SiyGeySnx alloys.pdf: 113 個片段 (0.1%)
# - ../PDF\Dabrowa …等 - 2019 - Demystifying the sluggish diffusion effect in high entropy alloys.pdf: 112 個片段 (0.1%)
# - ../PDF\Edalati …等 - 2021 - High-Pressure Torsion for Synthesis of High-Entropy Alloys.pdf: 112 個片段 (0.1%)
# - ../PDF\Liu …等 - 2023 - High-Temperature Mechanical Properties of NbTaHfTiZrV0.5 Refractory High-Entropy Alloys.pdf: 112 個片段 (0.1%)
# - ../PDF\Riva …等 - 2018 - The Effect of Scandium Ternary Intergrain Precipitates in Al-Containing High-Entropy Alloys.pdf: 112 個片段 (0.1%)
# - ../PDF\Sun …等 - 2024 - Heterogeneous Microstructure and Tensile Properties of Fe50Mn30Co10Cr10 Metastable High-Entropy Allo.pdf: 112 個片段 (0.1%)
# - ../PDF\Liu …等 - 2022 - Tensile creep behavior of HfNbTaTiZr refractory high entropy alloy at elevated temperatures.pdf: 111 個片段 (0.1%)
# - ../PDF\Yao …等 - 2016 - MoNbTaV Medium-Entropy Alloy.pdf: 111 個片段 (0.1%)
# - ../PDF\Zhang …等 - 2022 - A Strategic Design Route to Find a Depleted Uranium High-Entropy Alloy with Great Strength.pdf: 111 個片段 (0.1%)
# - ../PDF\Heterogeneous-structure-induced-strength-ductility-synergy-by-p_2021_Materia.pdf: 110 個片段 (0.1%)
# - ../PDF\Yurchenko …等 - 2016 - Phase Evolution of the AlxNbTiVZr (x=0; 0.5; 1; 1.5) High Entropy Alloys.pdf: 110 個片段 (0.1%)
# - ../PDF\Cui …等 - 2024 - Data driving design of high-entropy alloys for lightweight and dynamic applications.pdf: 109 個片段 (0.1%)
# - ../PDF\Development-of-oxidation-resistant-L12-strengthened-med_2025_Journal-of-Allo.pdf: 109 個片段 (0.1%)
# - ../PDF\Nagase …等 - 2020 - Alloy Design and Fabrication of Ingots of Al-Mg-Li-Ca Light-Weight Medium Entropy Alloys.pdf: 109 個片段 (0.1%)
# - ../PDF\Varcholová …等 - 2024 - New-Generation Materials for Hydrogen Storage in Medium-Entropy Alloys.pdf: 109 個片段 (0.1%)
# - ../PDF\Wang …等 - 2018 - Computation of entropies and phase equilibria in refractory V-Nb-Mo-Ta-W high-entropy alloys.pdf: 109 個片段 (0.1%)
# - ../PDF\Zyka …等 - 2019 - Microstructure and Room Temperature Mechanical Properties of Different 3 and 4 Element Medium Entrop.pdf: 109 個片段 (0.1%)
# - ../PDF\Jelen …等 - 2021 - Collective magnetism of a single-crystalline nanocomposite FeCoCrMnAl high-entropy alloy.pdf: 108 個片段 (0.1%)
# - ../PDF\Ortega …等 - 2022 - Production and characterization of the Cr35Fe35V16.5Mo6Ti7.5 high entropy alloy.pdf: 108 個片段 (0.1%)
# - ../PDF\Yao …等 - 2017 - Mechanical properties of refractory high-entropy alloys Experiments and modeling.pdf: 108 個片段 (0.1%)
# - ../PDF\Zhang …等 - 2021 - Elevated-temperature Deformation Mechanisms in a CrMnFeCoNi High-Entropy Alloy.pdf: 108 個片段 (0.1%)
# - ../PDF\Zheng …等 - 2021 - The Synthesis and Catalytic Applications of Nanosized High-Entropy Alloys.pdf: 108 個片段 (0.1%)
# - ../PDF\Effect-of-cell-wall-on-hydrogen-response-in-CoCrFeMnNi-hi_2022_Journal-of-Al.pdf: 107 個片段 (0.1%)
# - ../PDF\Senkov和Semiatin - 2015 - Microstructure and properties of a refractory high-entropy alloy after cold working.pdf: 107 個片段 (0.1%)
# - ../PDF\Su …等 - 2019 - Deformation-driven bidirectional transformation promotes bulk nanostructure formation in a metastabl.pdf: 107 個片段 (0.1%)
# - ../PDF\Tan …等 - 2018 - Microstructure characterization of CoCrFeNiMnPdx eutectic high-entropy alloys.pdf: 107 個片段 (0.1%)
# - ../PDF\Brito-Garcia …等 - 2023 - EIS Study of Doped High-Entropy Alloy.pdf: 106 個片段 (0.1%)
# - ../PDF\Elemental-effects-on-the-oxidation-of-re_2022_International-Journal-of-Refra.pdf: 106 個片段 (0.1%)
# - ../PDF\Tensile-properties-and-work-hardening-in-Al0-3CoCrFeNi--The-role_2024_Materi.pdf: 106 個片段 (0.1%)
# - ../PDF\Wu …等 - 2021 - Microstructure and deformation behavior of two TWIPTRIP high entropy alloys upon grain refinement.pdf: 106 個片段 (0.1%)
# - ../PDF\Elucidating-the-tensile-work-hardening-behaviour-of-precipitate-c_2024_Mater.pdf: 105 個片段 (0.1%)
# - ../PDF\Wang …等 - 2022 - High-entropy intermetallics from alloy design to structural and functional properties.pdf: 105 個片段 (0.1%)
# - ../PDF\Dasari …等 - 2023 - Exceptional enhancement of mechanical properties in high-entropy alloys via thermodynamically guided.pdf: 104 個片段 (0.1%)
# - ../PDF\Enhancement-of-fatigue-resistance-by-overload-induced-deformat_2020_Acta-Mat.pdf: 104 個片段 (0.1%)
# - ../PDF\Munitz …等 - 2018 - Microstructure and mechanical properties of heat treated Al1.25CoCrCuFeNi high entropy alloys.pdf: 104 個片段 (0.1%)
# - ../PDF\Oxidation-behaviour-of-Al2O3-forming-Cr-based-alloys-at-el_2024_Corrosion-Sc.pdf: 104 個片段 (0.1%)
# - ../PDF\Stability-of-the-B2-phase-in-Al-Nb-Ta-Ti-Zr-refractory-hig_2025_Journal-of-A.pdf: 104 個片段 (0.1%)
# - ../PDF\Vaidya …等 - 2020 - Phenomenon of ultra-fast tracer diffusion of Co in HCP high entropy alloys.pdf: 104 個片段 (0.1%)
# - ../PDF\Xiao …等 - 2017 - Microstructure, mechanical and corrosion behaviors of AlCoCuFeNi-(Cr,Ti) high entropy alloys.pdf: 104 個片段 (0.1%)
# - ../PDF\An-efficient-transient-three-dimensional-thermomechanic_2022_Journal-of-Mate.pdf: 103 個片段 (0.1%)
# - ../PDF\Moon …等 - 2020 - A new strategy for designing immiscible medium-entropy alloys with excellent tensile properties.pdf: 103 個片段 (0.1%)
# - ../PDF\Phase-equilibria-and-thermodynamic-assessment-of-the-Mo-Nb-Re-ter_2020_Calph.pdf: 103 個片段 (0.1%)
# - ../PDF\Srivastava …等 - 2017 - Processing of High-Entropy AlCoCr0.75Cu0.5FeNi Alloy by Spray Forming.pdf: 103 個片段 (0.1%)
# - ../PDF\An-effective-and-efficient-model-for-temperature-and_2021_Journal-of-Materia.pdf: 102 個片段 (0.1%)
# - ../PDF\Liu …等 - 2023 - High-Temperature Mechanical Behavior of Cobalt-Free FeMnCrNi(Al) High-Entropy Alloys.pdf: 102 個片段 (0.1%)
# - ../PDF\Przygucka …等 - 2025 - Titanium Oxide Formation in TiCoCrFeMn High-Entropy Alloys.pdf: 102 個片段 (0.1%)
# - ../PDF\Zhang …等 - 2020 - Nano-Scaled Creep Response of TiAlV Low Density Medium Entropy Alloy at Elevated Temperatures.pdf: 102 個片段 (0.1%)
# - ../PDF\Different-lattice-distortion-effects-on-the-tensile-properties-o_2021_Acta-M.pdf: 101 個片段 (0.1%)
# - ../PDF\Irradiation-effects-on-Al0-3CoCrFeNi-and-CoCrMnFeNi-high_2020_Journal-of-Nuc.pdf: 101 個片段 (0.1%)
# - ../PDF\Zeng …等 - 2024 - Machine learning accelerated discovery of corrosion-resistant high-entropy alloys.pdf: 101 個片段 (0.1%)
# - ../PDF\Evolution-of-hierarchical-structures-of-submicron-blocks-and-_2025_Materials.pdf: 100 個片段 (0.1%)
# - ../PDF\Kumar …等 - 2019 - Phase evolution of CoCrCuFeNiSix high-entropy alloys prepared by mechanical alloying and spark plasm.pdf: 100 個片段 (0.1%)
# - ../PDF\Muhammad …等 - 2024 - Oxidation Behavior of AlxHfNbTiVY0.05 Refractory High-Entropy Alloys at 700-900 °C.pdf: 100 個片段 (0.1%)
# - ../PDF\Nong …等 - 2017 - Prediction of structure and elastic properties of AlCrFeNiTi system high entropy alloys.pdf: 100 個片段 (0.1%)
# - ../PDF\Ren …等 - 2023 - Preparation and Microstructure of Multi-Component High Entropy Alloy Powders Fabricated by Gas Atomi.pdf: 100 個片段 (0.1%)
# - ../PDF\Soni和Sinha - 2023 - Effect of Alloying Elements, Phases and Heat Treatments on Properties of High-Entropy Alloys A Revi.pdf: 100 個片段 (0.1%)
# - ../PDF\Microstructure-and-tensile-property-of-a-precipitation-streng_2020_Additive-.pdf: 99 個片段 (0.1%)
# - ../PDF\Portevin-Le-Chatelier-mechanism-in-face-centered-cub_2019_International-Jour.pdf: 99 個片段 (0.1%)
# - ../PDF\Rogal …等 - 2019 - Microstructure and Mechanical Properties of Al-Co-Cr-Fe-Ni Base High Entropy Alloys Obtained Using P.pdf: 99 個片段 (0.1%)
# - ../PDF\Sun …等 - 2020 - Effect of SLM Processing Parameters on Microstructures and Mechanical Properties of Al0.5CoCrFeNi Hi.pdf: 99 個片段 (0.1%)
# - ../PDF\Tsai …等 - 2019 - Portevin-Le Chatelier mechanism in face-centered-cubic metallic alloys from low to high entropy.pdf: 99 個片段 (0.1%)
# - ../PDF\Wang …等 - 2023 - Investigation of the Micromechanical Behavior of a Ti68Nb7Ta3Zr4Mo18 (at.%) High-Entropy Alloy.pdf: 99 個片段 (0.1%)
# - ../PDF\1-s2.0-S2238785422018725-main.pdf: 98 個片段 (0.1%)
# - ../PDF\Biocompatible-as-cast-and-homogenized-TiNbTaZrMoV-hig_2023_Journal-of-Materi.pdf: 98 個片段 (0.1%)
# - ../PDF\Fatigue-behavior-of-a-wrought-Al0-5CoCrCuFeNi-two-phase-hig_2015_Acta-Materi.pdf: 98 個片段 (0.1%)
# - ../PDF\Huang …等 - 2019 - Machine-learning phase prediction of high-entropy alloys.pdf: 98 個片段 (0.1%)
# - ../PDF\Nagase …等 - 2022 - Design and development of (Ti, Zr, Hf)-Al based medium entropy alloys and high entropy alloys.pdf: 98 個片段 (0.1%)
# - ../PDF\Panahi …等 - 2022 - Effect of Si and B on the Electrochemical Behavior of FeCoNiCr-Based High-Entropy Amorphous Alloys.pdf: 98 個片段 (0.1%)
# - ../PDF\Prieto …等 - 2021 - Novel high entropy alloys as binder in cermets From design to sintering.pdf: 98 個片段 (0.1%)
# - ../PDF\Rogal …等 - 2017 - Effect of SiC nano-particles on microstructure and mechanical properties of the CoCrFeMnNi high entr.pdf: 98 個片段 (0.1%)
# - ../PDF\Sathiaraj …等 - 2016 - Microstructure and texture of heavily cold-rolled and annealed fcc equiatomic medium to high entropy.pdf: 98 個片段 (0.1%)
# - ../PDF\Sheikh …等 - 2018 - Accelerated oxidation in ductile refractory high-entropy alloys.pdf: 98 個片段 (0.1%)
# - ../PDF\Ye …等 - 2016 - The general effect of atomic size misfit on glass formation in conventional and high-entropy alloys.pdf: 98 個片段 (0.1%)
# - ../PDF\Zhang …等 - 2022 - Microstructure and Corrosion Behavior of Laser Cladding FeCoNiCrBSi Based High-Entropy Alloy Coating.pdf: 98 個片段 (0.1%)
# - ../PDF\Zhuang …等 - 2018 - Effect of Annealing on Microstructure and Mechanical Properties of Al0.5CoCrFeMoxNi High-Entropy All.pdf: 98 個片段 (0.1%)
# - ../PDF\Cai …等 - 2017 - Deformation mechanisms of Mo alloyed FeCoCrNi high entropy alloy In situ neutron diffraction.pdf: 97 個片段 (0.1%)
# - ../PDF\Salemi …等 - 2016 - Synthesis and thermodynamic analysis of nanostructured CuNiCoZnAl high entropy alloy produced by mec.pdf: 97 個片段 (0.1%)
# - ../PDF\Sokkalingam …等 - 2020 - Powder metallurgy of Al0.1CoCrFeNi high-entropy alloy.pdf: 97 個片段 (0.1%)
# - ../PDF\The-impact-of-grain-boundary-serration-treatments-on_2025_Materials-Science-.pdf: 97 個片段 (0.1%)
# - ../PDF\Tokarewicz …等 - 2022 - Investigation of the Structure and Corrosion Resistance of Novel High-Entropy Alloys for Potential B.pdf: 97 個片段 (0.1%)
# - ../PDF\Wu …等 - 2017 - Phase evolution and properties in laser surface alloying of FeCoCrAlCuNix high-entropy alloy on copp.pdf: 97 個片段 (0.1%)
# - ../PDF\Zhang …等 - 2021 - Microstructural evolution and strengthening mechanisms in CrxMnFeNi high-entropy alloy.pdf: 97 個片段 (0.1%)
# - ../PDF\A-perspective-on-the-catalysis-using-the-high-entropy-alloys_2021_Nano-Energ.pdf: 96 個片段 (0.1%)
# - ../PDF\Development-of-a-comprehensive-model-for-predicting-me_2023_Journal-of-Mater.pdf: 96 個片段 (0.1%)
# - ../PDF\Du …等 - 2023 - Dynamic Behavior of Additively Manufactured FeCoCrNi High Entropy Alloy.pdf: 96 個片段 (0.1%)
# - ../PDF\Gao …等 - 2017 - Computational modeling of high-entropy alloys Structures, thermodynamics and elasticity.pdf: 96 個片段 (0.1%)
# - ../PDF\Katiyar …等 - 2021 - A perspective on the catalysis using the high entropy alloys.pdf: 96 個片段 (0.1%)
# - ../PDF\Mixing-enthalpy-modulation-on-phase-transformation-in-the-gra_2025_Materials.pdf: 96 個片段 (0.1%)
# - ../PDF\Ozerov …等 - 2023 - Microstructure and Mechanical Properties of Biomedical Ti-Zr-Nb-Ta-Sn High-Entropy Alloys.pdf: 96 個片段 (0.1%)
# - ../PDF\Sokkalingam …等 - 2020 - Electron-beam welding of high-entropy alloy and stainless steel microstructure and mechanical prope.pdf: 96 個片段 (0.1%)
# - ../PDF\Chen和Lin - 2023 - Effects of Alloying Elements and Mechanical Alloying on Characteristics of WVTaTiCr Refractory High-.pdf: 95 個片段 (0.1%)
# - ../PDF\Tensile-creep-behavior-of-HfNbTaTiZr-refractory-high-entropy-_2022_Acta-Mate.pdf: 95 個片段 (0.1%)
# - ../PDF\Munitz …等 - 2017 - Liquid phase separation in transition element high entropy alloys.pdf: 94 個片段 (0.1%)
# - ../PDF\Wu …等 - 2024 - Relationship between the unique microstructures and behaviors of high-entropy alloys.pdf: 94 個片段 (0.1%)
# - ../PDF\Yang …等 - 2022 - Entropy versus enthalpy in hexagonal-close-packed high-entropy alloys.pdf: 94 個片段 (0.1%)
# - ../PDF\1-s2.0-S0966979519311021-main.pdf: 93 個片段 (0.1%)
# - ../PDF\Peltier …等 - 2022 - Damping Behavior in a Wide Temperature Range of FeMn-Like High Entropy Shape Memory Alloys.pdf: 93 個片段 (0.1%)
# - ../PDF\Ryltsev …等 - 2021 - Laves Phase Formation in High Entropy Alloys.pdf: 93 個片段 (0.1%)
# - ../PDF\Satyanarayana …等 - 2019 - Tungsten Matrix Composite Reinforced with CoCrFeMnNi High-Entropy Alloy Impact of Processing Routes.pdf: 93 個片段 (0.1%)
# - ../PDF\Wang …等 - 2018 - Evaluation of Radiation Response in CoCrFeCuNi High-Entropy Alloys.pdf: 93 個片段 (0.1%)
# - ../PDF\Yim …等 - 2017 - Shock wave compaction and sintering of mechanically alloyed CoCrFeMnNi high-entropy alloy powders.pdf: 93 個片段 (0.1%)
# - ../PDF\Yurchenko …等 - 2023 - Oxidation Behaviour of Refractory (HfCo)100-x(NbMo)x High-Entropy Alloys with a bcc+B2 Structure.pdf: 93 個片段 (0.1%)
# - ../PDF\Yurkova …等 - 2022 - Nanostructured AlCoFeCrVNi and AlCoFeCrVTi high-entropy alloys resulted from mechanical alloying and.pdf: 93 個片段 (0.1%)
# - ../PDF\Du …等 - 2021 - Mechanical and tribological performance of CoCrNiHfx eutectic medium-entropy alloys.pdf: 92 個片段 (0.1%)
# - ../PDF\Haas …等 - 2018 - Entropy Determination of Single-Phase High Entropy Alloys with Different Crystal Structures over a W.pdf: 92 個片段 (0.1%)
# - ../PDF\Madewu …等 - 2025 - Strength-Ductility Synergy of Lightweight High Entropy Alloys.pdf: 92 個片段 (0.1%)
# - ../PDF\Otto …等 - 2013 - Relative effects of enthalpy and entropy on the phase stability of equiatomic high-entropy alloys.pdf: 92 個片段 (0.1%)
# - ../PDF\Patel …等 - 2023 - Corrosion Behavior of Refractory High-Entropy Alloys in FLiNaK Molten Salts.pdf: 92 個片段 (0.1%)
# - ../PDF\Razumov …等 - 2021 - Refractory CrMoNbWV High-Entropy Alloy Manufactured by Mechanical Alloying and Spark Plasma Sinterin.pdf: 92 個片段 (0.1%)
# - ../PDF\Rogal - 2017 - Semi-solid processing of the CoCrCuFeNi high entropy alloy.pdf: 92 個片段 (0.1%)
# - ../PDF\Shittu …等 - 2020 - Biocompatible High Entropy Alloys with Excellent Degradation Resistance in a Simulated Physiological.pdf: 92 個片段 (0.1%)
# - ../PDF\Vrtnik …等 - 2018 - Magnetism of CoCrFeNiZrx eutectic high-entropy alloys.pdf: 92 個片段 (0.1%)
# - ../PDF\Xue …等 - 2024 - Research Progress of Al-Ti-V-based Lightweight High-Entropy Alloys.pdf: 92 個片段 (0.1%)
# - ../PDF\Yan …等 - 2022 - The oxidation-resistance mechanism of WTaNbTiAl refractory high entropy alloy.pdf: 92 個片段 (0.1%)
# - ../PDF\Zhang …等 - 2021 - Deformation twinning in Ti48.9Zr32.0Nb12.6Ta6.5 medium entropy alloy.pdf: 92 個片段 (0.1%)
# - ../PDF\Joo …等 - 2017 - Tensile deformation behavior and deformation twinning of an equimolar CoCrFeMnNi high-entropy alloy.pdf: 91 個片段 (0.1%)
# - ../PDF\Mundhra …等 - 2024 - Coupling CALPHAD Method and Entropy-Driven Design for the Development of an Advanced Lightweight Hig.pdf: 91 個片段 (0.1%)
# - ../PDF\Müller …等 - 2019 - On the oxidation mechanism of refractory high entropy alloys.pdf: 91 個片段 (0.1%)
# - ../PDF\Sun …等 - 2024 - High Temperature Oxidation Resistance of NiCoCrAl High Entropy Alloy Coating on the TiAl Alloy.pdf: 91 個片段 (0.1%)
# - ../PDF\Sure …等 - 2017 - Direct electrochemical synthesis of high-entropy alloys from metal oxides.pdf: 91 個片段 (0.1%)
# - ../PDF\Tripathi …等 - 2021 - Temperature-Dependent Superplasticity and Strengthening in CoNiCrFeMn High Entropy Alloy Nanowires U.pdf: 91 個片段 (0.1%)
# - ../PDF\Tsau和Lee - 2016 - Microstructures of Al7.5Cr22.5Fe35Mn20Ni15 High-Entropy Alloy and Its Polarization Behaviors in Sulf.pdf: 91 個片段 (0.1%)
# - ../PDF\Tseng …等 - 2019 - Effects of Mo, Nb, Ta, Ti, and Zr on Mechanical Properties of Equiatomic Hf-Mo-Nb-Ta-Ti-Zr Alloys.pdf: 91 個片段 (0.1%)
# - ../PDF\Yalamanchili …等 - 2017 - Exploring the high entropy alloy concept in (AlTiVNbCr)N.pdf: 91 個片段 (0.1%)
# - ../PDF\Zheng …等 - 2024 - Enhanced Magnetocaloric Properties of the (MnNi)0.6Si0.62(FeCo)0.4Ge0.38 High-Entropy Alloy Obtained.pdf: 91 個片段 (0.1%)
# - ../PDF\Liao …等 - 2020 - Development of Novel Lightweight Dual-Phase Al-Ti-Cr-Mn-V Medium-Entropy Alloys with High Strength a.pdf: 90 個片段 (0.1%)
# - ../PDF\On-the-phase-constituents-of-three-CoCrFeNiX--X---B--Al_2022_Journal-of-Allo.pdf: 90 個片段 (0.1%)
# - ../PDF\Plenge …等 - 2024 - Catalysis of C-N Coupling on High-Entropy Alloys.pdf: 90 個片段 (0.1%)
# - ../PDF\Zehtabi …等 - 2022 - Numerical Simulation of Cold Spray Bonding for CrFeNi Medium-Entropy Alloy.pdf: 90 個片段 (0.1%)
# - ../PDF\Zhao …等 - 2021 - Compositionally graded CoCrFeNiTix high-entropy alloys manufactured by laser powder bed fusion A co.pdf: 90 個片段 (0.1%)
# - ../PDF\In-situ-analysis-of-the-Portevin-Le-Chatelier-effect-from-low-_2023_Acta-Mat.pdf: 89 個片段 (0.1%)
# - ../PDF\Kai …等 - 2017 - Air-oxidation of FeCoNiCr-based quinary high-entropy alloys at 700-900 °C.pdf: 89 個片段 (0.1%)
# - ../PDF\Li和Tsai - 2020 - Theories for predicting simple solid solution high-entropy alloys Classification, accuracy, and imp.pdf: 89 個片段 (0.1%)
# - ../PDF\Mechanical-characteristic-comparison-of-additively-manu_2022_Materials-Scien.pdf: 89 個片段 (0.1%)
# - ../PDF\Savvotin …等 - 2023 - Thermochemical Analysis of Hydrogenation of Pd-Containing Composite Based on TiZrVNbTa High-Entropy.pdf: 89 個片段 (0.1%)
# - ../PDF\Singh …等 - 2021 - Fabrication of MgAlSiCrFe Low-Density High-Entropy Alloy by Mechanical Alloying and Spark Plasma Sin.pdf: 89 個片段 (0.1%)
# - ../PDF\Theories-for-predicting-simple-solid-solution-high-entropy-all_2020_Scripta-.pdf: 89 個片段 (0.1%)
# - ../PDF\Traversier …等 - 2021 - Nitrogen-induced hardening in an austenitic CrFeMnNi high-entropy alloy (HEA).pdf: 89 個片段 (0.1%)
# - ../PDF\Microstructure-evolution-in-high-pressure-phase-trans_2022_Journal-of-Alloys.pdf: 88 個片段 (0.1%)
# - ../PDF\Nadzri …等 - 2022 - High-Entropy Alloy for Thin Film Application A Review.pdf: 88 個片段 (0.1%)
# - ../PDF\Owen …等 - 2024 - Separation of static and dynamic displacements in the CrMnFeCoNi high entropy alloy.pdf: 88 個片段 (0.1%)
# - ../PDF\Poonia …等 - 2024 - Designing of high entropy alloys with high hardness a metaheuristic approach.pdf: 88 個片段 (0.1%)
# - ../PDF\Poulia …等 - 2016 - Microstructure and wear behavior of a refractory high entropy alloy.pdf: 88 個片段 (0.1%)
# - ../PDF\Sun …等 - 2024 - High-Entropy Alloys in Catalysis Progress, Challenges, and Prospects.pdf: 88 個片段 (0.1%)
# - ../PDF\Zhang …等 - 2020 - Effects of Cu and Zn on microstructures and mechanical behavior of the medium-entropy aluminum alloy.pdf: 88 個片段 (0.1%)
# - ../PDF\Hu …等 - 2023 - Microstructure Evolution and Mechanical Properties of a TiAl Alloy Modified by High-Entropy Alloy Ad.pdf: 87 個片段 (0.1%)
# - ../PDF\Joo …等 - 2017 - Structure and properties of ultrafine-grained CoCrFeMnNi high-entropy alloys produced by mechanical.pdf: 87 個片段 (0.1%)
# - ../PDF\Minor-tungsten-addition-enhances-corrosive-resistan_2024_Journal-of-Material.pdf: 87 個片段 (0.1%)
# - ../PDF\Oliveira …等 - 2020 - Gas tungsten arc welding of as-rolled CrMnFeCoNi high entropy alloy.pdf: 87 個片段 (0.1%)
# - ../PDF\Sun …等 - 2017 - Phase formations in low density high entropy alloys.pdf: 87 個片段 (0.1%)
# - ../PDF\Sun …等 - 2020 - Property tuning and additive manufacturing of refractory high-entropy alloys.pdf: 87 個片段 (0.1%)
# - ../PDF\Wu …等 - 2024 - Heterogeneous Microstructure Evolution and Mechanical Properties of a CrCoNiAl1Ti2 Medium-Entropy Al.pdf: 87 個片段 (0.1%)
# - ../PDF\Xiao …等 - 2023 - Environmental embrittlement behavior of high-entropy alloys.pdf: 87 個片段 (0.1%)
# - ../PDF\Xu …等 - 2020 - Microstructure Evolution and Mechanical Properties of FeCoCrNiCuTi0.8High-Entropy Alloy Prepared by.pdf: 87 個片段 (0.1%)
# - ../PDF\Allioux …等 - 2024 - Atomic Dispersion via High-Entropy Liquid Metal Alloys.pdf: 86 個片段 (0.1%)
# - ../PDF\Investigation-of-nanotwins-in-the-bimodal-structured-Fe22Co2_2020_Materials-.pdf: 86 個片段 (0.1%)
# - ../PDF\Lattice-distortion-effect-on-elastic-anisotropy-o_2020_Journal-of-Alloys-and.pdf: 86 個片段 (0.1%)
# - ../PDF\Microstructure-evolution-and-strain-rate-sensitivity-of-_2025_Journal-of-All.pdf: 86 個片段 (0.1%)
# - ../PDF\On-the-microstructure-and-properties-of-an-advanced-cem_2019_Journal-of-Allo.pdf: 86 個片段 (0.1%)
# - ../PDF\Raabe …等 - 2015 - From High-Entropy Alloys to High-Entropy Steels.pdf: 86 個片段 (0.1%)
# - ../PDF\Sheikh …等 - 2020 - Alloying effect on the oxidation behavior of a ductile Al0.5Cr0.25Nb0.5Ta0.5Ti1.5 refractory high-en.pdf: 86 個片段 (0.1%)
# - ../PDF\Takeuchi - 2020 - Mixing Entropy of Exact Equiatomic High-Entropy Alloys Formed into a Single Phase.pdf: 86 個片段 (0.1%)
# - ../PDF\Tan …等 - 2022 - Design principles of low-activation high entropy alloys.pdf: 86 個片段 (0.1%)
# - ../PDF\Wang …等 - 2022 - Tribocorrosion Behavior of CoCrNi Medium Entropy Alloy in Simulated Seawater.pdf: 86 個片段 (0.1%)
# - ../PDF\Wu …等 - 2017 - Phase evolution and cavitation erosion-corrosion behavior of FeCoCrAlNiTix high entropy alloy coatin.pdf: 86 個片段 (0.1%)
# - ../PDF\Ye …等 - 2015 - A geometric model for intrinsic residual strain and phase stability in high entropy alloys.pdf: 86 個片段 (0.1%)
# - ../PDF\Zhao …等 - 2020 - Fabrication and friction properties of the AlFeCrCo medium-entropy alloy coatings on magnesium alloy.pdf: 86 個片段 (0.1%)
# - ../PDF\Cryogenic-strengthening-of-Fe27Co24Ni23Cr26-high-entr_2024_Materials-Science.pdf: 85 個片段 (0.1%)
# - ../PDF\Rao …等 - 2021 - Beyond Solid Solution High-Entropy Alloys Tailoring Magnetic Properties via Spinodal Decomposition.pdf: 85 個片段 (0.1%)
# - ../PDF\Refractory-high-entropy-superalloys--RSAs-_2020_Scripta-Materialia.pdf: 85 個片段 (0.1%)
# - ../PDF\The-growth-activation-energy-of-sigma-phase-in-nonequal_2025_Journal-of-Allo.pdf: 85 個片段 (0.1%)
# - ../PDF\Tseng …等 - 2022 - Edge-dislocation-induced ultrahigh elevated-temperature strength of HfMoNbTaW refractory high-entrop.pdf: 85 個片段 (0.1%)
# - ../PDF\Zhou …等 - 2024 - Effect of Cooling Method on Microstructure and Microhardness of CuCrFeMnNi High-Entropy Alloy.pdf: 85 個片段 (0.1%)
# - ../PDF\Corrosion-mechanism-of-annealed-equiatomic-AlCoCrFeNi-tri-phas_2019_Corrosio.pdf: 84 個片段 (0.1%)
# - ../PDF\Influence-of-pre-deformation-on-the-precipitation-characte_2021_Journal-of-A.pdf: 84 個片段 (0.1%)
# - ../PDF\Li …等 - 2020 - Preternatural Hexagonal High-Entropy Alloys A Review.pdf: 84 個片段 (0.1%)
# - ../PDF\Liu …等 - 2020 - Self-sharpening tungsten high-entropy alloy.pdf: 84 個片段 (0.1%)
# - ../PDF\Microstructure-and-property-of-a-selective-laser-melting-_2019_Journal-of-Al.pdf: 84 個片段 (0.1%)
# - ../PDF\Paul …等 - 2018 - Analysis of diffusion in high entropy alloys.pdf: 84 個片段 (0.1%)
# - ../PDF\Sveda …等 - 2024 - Microstructure evolution and catalytic activity of AlCo1-xFeNiTiMox high entropy alloys fabricated b.pdf: 84 個片段 (0.1%)
# - ../PDF\Tazuddin …等 - 2017 - In the quest of single phase multi-component multiprincipal high entropy alloys.pdf: 84 個片段 (0.1%)
# - ../PDF\Differences-in-texture-evolution-from-low-entropy-to-high-entro_2020_Interme.pdf: 83 個片段 (0.1%)
# - ../PDF\Fan …等 - 2020 - On the phase constituents of four CoCrFeNiX (X = Y, Ti, Zr, Hf) high-entropy alloys after prolonged.pdf: 83 個片段 (0.1%)
# - ../PDF\Huang …等 - 2018 - Wear and Corrosion Resistance of Al0.5CoCrCuFeNi High-Entropy Alloy Coating Deposited on AZ91D Magne.pdf: 83 個片段 (0.1%)
# - ../PDF\Löffler …等 - 2021 - What Makes High-Entropy Alloys Exceptional Electrocatalysts.pdf: 83 個片段 (0.1%)
# - ../PDF\Medina …等 - 2020 - Phase formation in magnetron sputtered CrMnFeCoNi high entropy alloy.pdf: 83 個片段 (0.1%)
# - ../PDF\On-the-phase-constituents-of-four-CoCrFeNiX--X-Y--_2020_Journal-of-Materials.pdf: 83 個片段 (0.1%)
# - ../PDF\Shafiei - 2021 - Design of Eutectic High Entropy Alloys in Al-Co-Cr-Fe-Ni System.pdf: 83 個片段 (0.1%)
# - ../PDF\Sinha …等 - 2021 - Influence of Refractory Elements on Mechanical Properties of High Entropy Alloys.pdf: 83 個片段 (0.1%)
# - ../PDF\Yurkova …等 - 2019 - Structure formation and mechanical properties of the high-entropy AlCuNiFeCr alloy prepared by mecha.pdf: 83 個片段 (0.1%)
# - ../PDF\Investigation-on-the-thermal-expansion-behavior-of-FeC_2021_Materials-Chemis.pdf: 82 個片段 (0.1%)
# - ../PDF\Lin …等 - 2021 - Investigation on the thermal expansion behavior of FeCoNi and Fe30Co30Ni30Cr10-xMnx high entropy all.pdf: 82 個片段 (0.1%)
# - ../PDF\Nassar …等 - 2022 - Rapid solidification of AlCoCrFeNi2.1 High-entropy Alloy.pdf: 82 個片段 (0.1%)
# - ../PDF\Nene …等 - 2020 - Microstructurally flexible high entropy alloys Linkages between alloy design and deformation behavi.pdf: 82 個片段 (0.1%)
# - ../PDF\Shivam …等 - 2018 - Mechano-chemical synthesis, thermal stability and phase evolution in AlCoCrFeNiMn high entropy alloy.pdf: 82 個片段 (0.1%)
# - ../PDF\Wang …等 - 2015 - Microstructure, thermodynamics and compressive properties of AlCoCrCuMn-x (x = Fe, Ti) high-entropy.pdf: 82 個片段 (0.1%)
# - ../PDF\Wang …等 - 2018 - Mechanical Properties and Microstructure of a NiCrFeCoMn High-Entropy Alloy Deformed at High Strain.pdf: 82 個片段 (0.1%)
# - ../PDF\Wu …等 - 2018 - Effect of Atomic Size Difference on the Microstructure and Mechanical Properties of High-Entropy All.pdf: 82 個片段 (0.1%)
# - ../PDF\Godlewska …等 - 2020 - Corrosion of Al(Co)CrFeNi High-Entropy Alloys.pdf: 81 個片段 (0.1%)
# - ../PDF\John …等 - 2020 - Microstructure and mechanical properties of a high entropy alloy with a eutectic composition (AlCoCr.pdf: 81 個片段 (0.1%)
# - ../PDF\Ko …等 - 2022 - Microstructure and Mechanical Properties of Intergranular Boride Precipitation-Toughened HfMoNbTaTiZ.pdf: 81 個片段 (0.1%)
# - ../PDF\Liu …等 - 2023 - Progress of Cryogenic Deformation and Strengthening-Toughening Mechanisms of High-Entropy Alloys.pdf: 81 個片段 (0.1%)
# - ../PDF\On-the-phase-constituents-of-three-CoCrFeNiX--X---Cr--M_2022_Materials-Chemi.pdf: 81 個片段 (0.1%)
# - ../PDF\Sure …等 - 2019 - Electrochemical conversion of oxide spinels into high-entropy alloy.pdf: 81 個片段 (0.1%)
# - ../PDF\Ter-Isahakyan …等 - 2022 - High entropy alloys with hexagonal close-packed structure derived from thin film combinatorial appro.pdf: 81 個片段 (0.1%)
# - ../PDF\Thürmer …等 - 2022 - Exceptionally high spallation strength for a high-entropy alloy demonstrated by experiments and simu.pdf: 81 個片段 (0.1%)
# - ../PDF\Torabizadeh …等 - 2019 - Microstructure and Mechanical Properties of Nanostructured CoCrFeMoTi High-Entropy Alloy Fabricated.pdf: 81 個片段 (0.1%)
# - ../PDF\Verma …等 - 2017 - On Interdiffusion in FeNiCoCrMn High Entropy Alloy.pdf: 81 個片段 (0.1%)
# - ../PDF\Zhou和He - 2020 - Synthesis of the New High Entropy Alloy and Its Application in Energy Conversion and Storage.pdf: 81 個片段 (0.1%)
# - ../PDF\Enhancing-ionic-conductivity-and-air-stability-of-Li7La3_2025_Journal-of-All.pdf: 80 個片段 (0.1%)
# - ../PDF\Li …等 - 2025 - Effects of Zr Alloying on Microstructure Evolution and Mechanical Properties of CoCrNi Medium Entrop.pdf: 80 個片段 (0.1%)
# - ../PDF\Rajabi …等 - 2024 - Tribological Behavior and In-Vitro Biocompatibility of a Newly Designed TiZrNbMoTa High-Entropy Allo.pdf: 80 個片段 (0.1%)
# - ../PDF\Ratajczyk和Donten - 2024 - Comparative Analysis of Metal Electrodeposition Rates towards Formation of High-Entropy WFeCoNiCu Al.pdf: 80 個片段 (0.1%)
# - ../PDF\Rhode …等 - 2024 - Local mechanical properties of dissimilar metal TIG welded joints of CoCrFeMnNi high entropy alloy a.pdf: 80 個片段 (0.1%)
# - ../PDF\Sfikas …等 - 2023 - Microstructural Evaluation of Thermal-Sprayed CoCrFeMnNi0.8V High-Entropy Alloy Coatings.pdf: 80 個片段 (0.1%)
# - ../PDF\Yaykasli …等 - 2024 - Microstructure and Thermal and Radiation Shielding Properties of CoCrFeNiAg High Entropy Alloy.pdf: 80 個片段 (0.1%)
# - ../PDF\-AlCrNbSiTi-N-TiN-multilayer-films-designed-by-a-hybrid-co_2023_Surface-and-.pdf: 79 個片段 (0.1%)
# - ../PDF\Jumaev …等 - 2019 - Chemical evolution-induced strengthening on AlCoCrNi dual-phase high-entropy alloy with high specifi.pdf: 79 個片段 (0.1%)
# - ../PDF\Kumar …等 - 2018 - Phase Evolution and Mechanical Properties of AlCoCrFeNiSi x High-Entropy Alloys Synthesized by Mecha.pdf: 79 個片段 (0.1%)
# - ../PDF\Mints …等 - 2022 - Exploring the Composition Space of High-Entropy Alloy Nanoparticles for the Electrocatalytic H2CO O.pdf: 79 個片段 (0.1%)
# - ../PDF\Oates - 2007 - Configurational entropies of mixing in solid alloys.pdf: 79 個片段 (0.1%)
# - ../PDF\Pedersen …等 - 2020 - High-Entropy Alloys as Catalysts for the CO2 and CO Reduction Reactions.pdf: 79 個片段 (0.1%)
# - ../PDF\Que …等 - 2024 - Toward a better understanding of the photothermal heating of high-entropy-alloy nanoparticles.pdf: 79 個片段 (0.1%)
# - ../PDF\Stoian …等 - 2023 - Complex Bioactive Chitosan-Bioglass Coatings on a New Advanced TiTaZrAg Medium-High-Entropy Alloy.pdf: 79 個片段 (0.1%)
# - ../PDF\Tensile-overload-induced-texture-effects-on-the-fatigue-resis_2023_Acta-Mate.pdf: 79 個片段 (0.1%)
# - ../PDF\Wang …等 - 2024 - Hot Deformation Behavior of Fe40Mn20Cr20Ni20 Medium-Entropy Alloy.pdf: 79 個片段 (0.1%)
# - ../PDF\Zhang …等 - 2017 - Microstructure and mechanical behaviors of Gd CoCrCuFeNi high-entropy alloys.pdf: 79 個片段 (0.1%)
# - ../PDF\Farquhar …等 - 2022 - In-Situ Alloying of CoCrFeNiX High Entropy Alloys by Selective Laser Melting.pdf: 78 個片段 (0.1%)
# - ../PDF\Geambazu …等 - 2021 - Mechanically Alloyed CoCrFeNiMo0.85 High-Entropy Alloy for Corrosion Resistance Coatings.pdf: 78 個片段 (0.1%)
# - ../PDF\Grain-boundary-serration-tuning-and-its-effect-on-ho_2023_Journal-of-Alloys-.pdf: 78 個片段 (0.1%)
# - ../PDF\Liu …等 - 2018 - Precipitation hardening in CoCrFeNi-based high entropy alloys.pdf: 78 個片段 (0.1%)
# - ../PDF\Park …等 - 2018 - Effect of annealing heat treatment on microstructural evolution and tensile behavior of Al0.5CoCrFeM.pdf: 78 個片段 (0.1%)
# - ../PDF\Qiu …等 - 2015 - Corrosion characteristics of high entropy alloys.pdf: 78 個片段 (0.1%)
# - ../PDF\Takeuchi …等 - 2015 - Alloy design for high-entropy alloys based on Pettifor map for binary compounds with 11 stoichiomet.pdf: 78 個片段 (0.1%)
# - ../PDF\Tang …等 - 2014 - Alloying and Processing Effects on the Aqueous Corrosion Behavior of High-Entropy Alloys.pdf: 78 個片段 (0.1%)
# - ../PDF\Wang …等 - 2018 - Effect of Cold Rolling on the Phase Transformation Kinetics of an Al0.5CoCrFeNi High-Entropy Alloy.pdf: 78 個片段 (0.1%)
# - ../PDF\Yang …等 - 2019 - Nanoporous Quasi-High-Entropy Alloy Microspheres.pdf: 78 個片段 (0.1%)
# - ../PDF\Hemphill …等 - 2012 - Fatigue behavior of Al0.5CoCrCuFeNi high entropy alloys.pdf: 77 個片段 (0.1%)
# - ../PDF\Hydrogen-storage-properties-of-multi-principal-_2010_International-Journal-o.pdf: 77 個片段 (0.1%)
# - ../PDF\Microstructure-and-texture-evolution-during-annealing-_2014_Journal-of-Alloy.pdf: 77 個片段 (0.1%)
# - ../PDF\Novák和Nová - 2021 - Novel High-Entropy Aluminide-Silicide Alloy.pdf: 77 個片段 (0.1%)
# - ../PDF\Rahman …等 - 2022 - Synthesis, microstructure, and thermoelectric properties of Sb-Based high entropy alloys.pdf: 77 個片段 (0.1%)
# - ../PDF\Tian …等 - 2024 - Effect of Alloying on Microstructure and Mechanical Properties of AlCoCrFeNi2.1 Eutectic High-Entrop.pdf: 77 個片段 (0.1%)
# - ../PDF\Tun …等 - 2021 - Lightweight Medium Entropy Magnesium Alloy with Exceptional Compressive Strength and Ductility Combi.pdf: 77 個片段 (0.1%)
# - ../PDF\Wang …等 - 2018 - Phase Transformation Kinetics of a FCC Al0.25CoCrFeNi High-Entropy Alloy during Isochronal Heating.pdf: 77 個片段 (0.1%)
# - ../PDF\Wei …等 - 2021 - Research progress in high entropy alloys by additive manufacturing.pdf: 77 個片段 (0.1%)
# - ../PDF\Xiao …等 - 2020 - Ultra-strong nanostructured CrMnFeCoNi high entropy alloys.pdf: 77 個片段 (0.1%)
# - ../PDF\Zhao …等 - 2016 - A hexagonal close-packed high-entropy alloy The effect of entropy.pdf: 77 個片段 (0.1%)
# - ../PDF\Zhao …等 - 2019 - Tribological behavior of an amorphous Zr20Ti20Cu20Ni20Be20 high-entropy alloy studied using a nanosc.pdf: 77 個片段 (0.1%)
# - ../PDF\Zhu …等 - 2023 - Ultrastrong High-Ductility Ni35Co35Fe10Al10Ti8B2 High-Entropy Alloy Strengthened with Super-High Con.pdf: 77 個片段 (0.1%)
# - ../PDF\Bottom-up-characterization-of-electrochemical-passivity-from_2022_Electrochi.pdf: 76 個片段 (0.1%)
# - ../PDF\Corrosion-of-plasma-sputtering-medium-entropy-alloy-thin-fil_2023_Corrosion-.pdf: 76 個片段 (0.1%)
# - ../PDF\Enhanced-age-hardening-effects-in-FCC-based-Co1-5CrFeNi1-5-high-e_2020_Mater.pdf: 76 個片段 (0.1%)
# - ../PDF\Jo …等 - 2019 - Cryogenic-temperature fracture toughness analysis of non-equi-atomic V10Cr10Fe45Co20Ni15 high-entrop.pdf: 76 個片段 (0.1%)
# - ../PDF\Lindner …等 - 2017 - The Phase Composition and Microstructure of AlxCoCrFeNiTi Alloys for the Development of High-Entropy.pdf: 76 個片段 (0.1%)
# - ../PDF\Rao …等 - 2016 - Affordable FeCrNiMnCu high entropy alloys with excellent comprehensive tensile properties.pdf: 76 個片段 (0.1%)
# ...
# interactions ofdiverse elements, enha...
# 77 | ../PDF\Mints …等 - 2022 - Exploring the Composition Space of High-Entropy Alloy Nanoparticles for the Electrocatalytic H2CO O.pdf | 7 | 769 | (27)Pedersen, J.K.;Clausen, C.M.;Krysiak,O.A.;Xiao,B.;
# Batchelor, T.A.A.;Löffler,T.;Mints,V.A.;Banko...
# 78 | ../PDF\Sun …等 - 2024 - High-Entropy Alloys in Catalysis Progress, Challenges, and Prospects.pdf | 1 | 785 | collectively influence their behavior and performance and offer
# unique properties forelectrocatalysi...
# 79 | ../PDF\high-entropy-alloys-as-catalysts-for-the-co2-and-co-reduction-reactions.pdf | 11 | 721 | Materials 5, 70. https://doi.org/10.1038/s41524-019-0205-0. 242
# [3] L¨ oﬄer, T., Meyer, H., Savan, A...
# 80 | ../PDF\High‐entropy alloy catalysts_ From bulk to nano toward highly efficient carbon and nitrogen catalysis - Yu - 2022 - Carbon Energy - Wiley Online Library.pdf | 41 | 710 | 36Batchelor TAA , Pedersen JK , Winther SH , Castelli IE , Jacobsen KW , Rossmeisl J . High-entropy
# ...
# 81 | ../PDF\Li …等 - 2019 - Mechanical properties of high-entropy alloys with emphasis on face-centered cubic alloys.pdf | 7 | 776 | catalysis applications. The elements in precious me tal HEAs are mainly Ag, Au, Co, Cr, Cu, Ni,
# Pd,...
# 82 | ../PDF\Sun …等 - 2024 - High-Entropy Alloys in Catalysis Progress, Challenges, and Prospects.pdf | 3 | 670 | metal−air batteries, iscritical.51,52These technologies often
# require noble metals like Pt,Ru, and I...
# 83 | ../PDF\high-entropy-alloys-as-catalysts-for-the-co2-and-co-reduction-reactions.pdf | 0 | 558 | compounds is expected, as well as insights into the rational design of disordered alloy catalysts 18...
# 84 | ../PDF\high-entropy-alloys-as-catalysts-for-the-co2-and-co-reduction-reactions.pdf | 12 | 477 | (2019). High-Entropy Alloys as a Discovery Platform for Electrocatalysis. Joule 3, 834 – 845. https:...
# 85 | ../PDF\Zheng …等 - 2021 - The Synthesis and Catalytic Applications of Nanosized High-Entropy Alloys.pdf | 7 | 375 | generate commodity che micals and carbon -based fuels.[87-89] The
# reduct ion process usually involv...
# 86 | ../PDF\High‐entropy alloy catalysts_ From bulk to nano toward highly efficient carbon and nitrogen catalysis - Yu - 2022 - Carbon Energy - Wiley Online Library.pdf | 51 | 760 | 123 Nie S , Wu L , Zhao L , Zheng X , Yang S , Zhang P . Entropy-driven chemistry reveals highly sta...
# 87 | ../PDF\Pedersen …等 - 2020 - High-Entropy Alloys as Catalysts for the CO2 and CO Reduction Reactions.pdf | 7 | 798 | (29) Batchelor, T. A. A.; Pedersen, J. K.; Winther, S. H.; Castelli, I.
# E.; Jacobsen, K. W.; Rossmei...
# 88 | ../PDF\Pedersen …等 - 2021 - Bayesian Optimization of High-Entropy Alloy Compositions for Electrocatalytic Oxygen Reduction.pdf | 0 | 793 | ableenergy conversion inorder tomeet theincreasing global
# energy demand andtocombat climate change ....
# 89 | ../PDF\Zhang …等 - 2024 - Frontiers in high entropy alloys and high entropy functional materials.pdf | 89 | 285 | of active species [776, 781]. The coordination environment
# and wide diversity of oxidation states o...
# 90 | ../PDF\Zhang …等 - 2024 - Frontiers in high entropy alloys and high entropy functional materials.pdf | 66 | 759 | 4705
# Frontiers in high entropy alloys and high entropy functional materials
# Rare Met. (2024) 43(10):...
# 91 | ../PDF\Mints …等 - 2022 - Exploring the Composition Space of High-Entropy Alloy Nanoparticles for the Electrocatalytic H2CO O.pdf | 0 | 799 | catalysisisthatRufacilitates theformation ofadsorbed OH
# speciesatlowerpotentials.12Theseadsorbed OHs...
# 92 | ../PDF\Zhang …等 - 2024 - Frontiers in high entropy alloys and high entropy functional materials.pdf | 58 | 790 | nFeCoNi non-noble high-entropy alloy nanoparticles as
# catalytic materials (Fig.  49f). Electrochemi...
# 93 | ../PDF\High‐entropy alloy catalysts_ From bulk to nano toward highly efficient carbon and nitrogen catalysis - Yu - 2022 - Carbon Energy - Wiley Online Library.pdf | 49 | 760 | CAS PubMed Web of Science® Google Scholar
# 104 Jin Z , Lyu J , Hu K , et al. Eight-component nanoporo...
# 94 | ../PDF\Sun …等 - 2024 - High-Entropy Alloys in Catalysis Progress, Challenges, and Prospects.pdf | 8 | 773 | K.D.;Pradeep, K.G.;Singh, A.K.;Sharma, S.;Tiwary, C.S.;Biswas,
# K.High-entropy Alloys asCatalysts for...
# 95 | ../PDF\High‐entropy alloy catalysts_ From bulk to nano toward highly efficient carbon and nitrogen catalysis - Yu - 2022 - Carbon Energy - Wiley Online Library.pdf | 39 | 794 | CAS PubMed Web of Science® Google Scholar
# 20Jiao F , Xu B . Electrochemical ammonia synthesis and am...
# 96 | ../PDF\Sun …等 - 2024 - High-Entropy Alloys in Catalysis Progress, Challenges, and Prospects.pdf | 8 | 782 | 4211.
# (53) Quaino, P.;Juarez, F.;Santos, E.;Schmickler, W.Volcano Plots
# inHydrogen Electrocatalysis ...
# 97 | ../PDF\Zheng …等 - 2021 - The Synthesis and Catalytic Applications of Nanosized High-Entropy Alloys.pdf | 10 | 798 | Ir10.2Pd32.0Pt9.30Rh19.6Ru28.9 and d) Ir17.5Pt82.5. (Reproduced from Ref. [ 100] with
# permission.  ...
# 98 | ../PDF\Allioux …等 - 2024 - Atomic Dispersion via High-Entropy Liquid Metal Alloys.pdf | 1 | 783 | Furthermore, the combination of noble metals such as Au, Pt,
# Pd, along with transition metals like C...
# 99 | ../PDF\Löffler …等 - 2021 - What Makes High-Entropy Alloys Exceptional Electrocatalysts.pdf | 1 | 754 | Chemical intuition approaches for
# HEAs already yielded catalysts that
# cancompete with state-of-the-a...
#
# ===== 2025-04-12 16:00:36 =====
# 🧪 問題：哪一組合金性能最好？
# 🔍 會話ID: chen03, 檢索數量: 20
#
# ⏳ 正在檢索與「哪一組合金性能最好？」相關的文檔，檢索數量: 20
# ⚠️ 帶分數檢索方法不可用，回退到普通檢索
# 2025-04-12 16:00:37,727 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 📊 檢索統計:
# - 共檢索到 20 個文檔片段
# - 來自 12 個不同來源
# - 檢索耗時: 1.51 秒
#
# 📑 檢索文檔詳情:
# 索引 | 來源 | 頁碼 | 內容長度 | 內容預覽
# ----- | ----- | ----- | ----- | -----
# 0 | ../PDF\Xu …等 - 2022 - Toughening Pathways and Regulatory Mechanisms of Refractory High-Entropy Alloys.pdf | 4 | 759 | 力学性能 。Huang等[36]设计的 TaxHfZrTi双相难熔高
# 熵合金表现出较大的延伸率 ，由于 TRIP效应诱导
# hcp相形成，合金中 bcc相和 hcp相之间的动态应变 -
# 应力分配产生强烈...
# 1 | ../PDF\Zhao …等 - 2024 - Research Status of Phase Transformation Behavior of High Entropy Shape Memory Alloys.pdf | 3 | 668 | 当Cr含量为 10%（质量分数）时合金性能较好。朱琳[44]
# 研究了 AlCoCrFeNi x在热处理过程中的相变行为，如图 3
# 所示。当 x=0.4，0.8时，在 600 ℃发生单一的可逆相变。
# 当...
# 2 | ../PDF\Xu …等 - 2022 - Toughening Pathways and Regulatory Mechanisms of Refractory High-Entropy Alloys.pdf | 7 | 410 | 开发具有高强高韧的金属材料一直是材料领域
# 的研究热门 。传统金属材料常采用细晶强化 、固溶
# 强化、第二相强化和相变强化等强韧化手段达到改
# 善力学性能的目的 ，就目前研究而言 ，只有绝大部分
# 3d过渡金...
# 3 | ../PDF\Liu …等 - 2023 - Progress of Cryogenic Deformation and Strengthening-Toughening Mechanisms of High-Entropy Alloys.pdf | 9 | 799 | 59 卷 金 属 学 报
# 超高强度水平 ，同时还保持 53%的优异延伸率 ，如
# 图10b[91]所示。
# 另外，结合析出强化和相转变行为的耦合强韧
# 化机制也被应用于提升高熵合金的性能 。2020年，
# D...
# 4 | ../PDF\Xu …等 - 2022 - Toughening Pathways and Regulatory Mechanisms of Refractory High-Entropy Alloys.pdf | 7 | 791 | Ti2Al4不仅抗拉强度显著提高 ，稳态蠕变速率也降低
# 了约 2个数量级 ，表明其高温性能显著改善[99]。目
# 前，难熔高熵合金的高温蠕变性能尚未见报道 。
# 3难熔高熵合金的力学性能调控
# 难熔高熵合金...
# 5 | ../PDF\Lu …等 - 2018 - Deformation Behavior and Toughening of High-Entropy Alloys.pdf | 1 | 778 | 将合金的性能达到最优化 。已开发研究的合金体系
# 大体可以分为 2大类：一类是以 Al及第 IV周期元素
# Fe、Co、Ni、Cr、Cu、Mn、Ti为主的合金系 ；一类是以
# 难熔金属元素 Mo、Ti、V、...
# 6 | ../PDF\Huang …等 - 2021 - Preparation, structures and properties of tungsten-containing refractory high entropy alloys.pdf | 1 | 773 | 1   引　言
# 未来核聚变反应堆第一面向等离子材料所面
# 临的工况条件是: 工作温度为570—1270 K, 热负
# 荷为2—20 MW/m2, 中子通量为每个原子数个位
# 移的累积(dpa)/年[1 −5...
# 7 | ../PDF\Yang …等 - 2020 - Microscopic phase-field simulation for precipitation process of Ni60Al20V20 medium entropy alloy.pdf | 1 | 545 | 合金强度和延展性, Zhao等[10]对CoCrNi中熵合
# 金研究表明, 中熵合金经纳米L12结构  相沉淀强
# 化, 其屈服强度和抗拉强度分别提高70%和45%.
# 目前对中熵合金研究主要集中在制备方...
# 8 | ../PDF\Ma …等 - 2024 - Microstructure and Properties of Fe2-xCrMnAlxCu High Entropy Alloy.pdf | 0 | 782 | 晶组织均由 bcc相构成，且枝晶内部析出有序 bcc结构的 FeAl相。随着 Fe含量减少， Al含量的增加，其析出物含量
# 略微增加，使得 Fe2-xCrMnAl xCu高熵合金的硬度不断增加。当 x...
# 9 | ../PDF\Sun …等 - 2020 - Property tuning and additive manufacturing of refractory high-entropy alloys.pdf | 2 | 795 | 增材制
# 造成形和应用进行了展望
# 。
# １
#
# 难熔高熵合金的性能调控
# 高强度与良好的塑性一直是材料研发中的热点问
# 题
# ，
# 两者相对制约的关系使得大多数材料在强化时导
# 致塑性变形能力降低
# ，
# 因此实现材料...
# 10 | ../PDF\Wang …等 - 2025 - Revisiting the Development of Eutectic High-Entropy Alloys over the Past Decade (2014--2024)Design,.pdf | 5 | 781 | 变形量冷轧后进行等温退火 ，可获得具有等轴超细晶的两相组织 ，使AlCoCrFeNi2.1合金强度得以大幅度
# 提升[53,55]。而通过中温轧制能够调控出同时包含等轴
# 和层片组织的异质结构共晶高熵合金...
# 11 | ../PDF\Wu …等 - 2024 - Effect of AlCoCrFeNi High-Entropy Alloy on Microstructure and Mechanical Properties of Al-Si-Cu Allo.pdf | 8 | 760 | Wu Qingjie et al . / Rare Metal Materials and Engineering , 2024 , 53(11):3017 -3025
# Science & Techn...
# 12 | ../PDF\Liu …等 - 2023 - Progress of Cryogenic Deformation and Strengthening-Toughening Mechanisms of High-Entropy Alloys.pdf | 11 | 771 | 4.2 低温超高强度高熵合金的韧塑化机理
# 目前虽有少量 2 GPa高熵合金的研究报
# 道[42,48,91,103~106]，但大多数合金的低温屈服强度在
# 1.5 GPa以下，没有展现出超高强韧高熵合金...
# 13 | ../PDF\Lu …等 - 2018 - Deformation Behavior and Toughening of High-Entropy Alloys.pdf | 6 | 666 | 单相 bcc高熵合金具有较高的强度 ，但其塑性较低 ，
# 比如 TaHfZrTi 具有 1.5GPa的高拉伸强度 ，但其塑性
# 只有大约 4%[11]。另外，由于包含多种高浓度的元
# 素，高熵合金具有较差的...
# 14 | ../PDF\Wang …等 - 2025 - Revisiting the Development of Eutectic High-Entropy Alloys over the Past Decade (2014--2024)Design,.pdf | 6 | 765 | 环境下可以形成致密而稳定的 Fe-Cr-Al-O 氧化膜，
# 显著阻碍了液态 Pb-Bi向基体的扩散和溶解 。相比
# 于传统的铁素体 /马氏体钢和奥氏体不锈钢 ，该合金
# 在高温 Pb-Bi环境中更为稳定 ...
# 15 | ../PDF\Huang …等 - 2021 - Preparation, structures and properties of tungsten-containing refractory high entropy alloys.pdf | 6 | 778 | 采用真空电弧熔炼法制备了该合金, 并对其性能进
# 行了探讨. 研究发现, 在600—800 °C温度下, 抗
# 压屈服强度超过1000 MPa, 具有优异的耐热抗软
# 化性能.
# 众所周知[86 −88], ...
# 16 | ../PDF\Wang …等 - 2024 - Research progress in dynamic mechanical behavior of high-entropy alloys.pdf | 8 | 777 | BCC结构高熵合金强度较高 ，但塑性和应变硬化
# 能力较差 ，主要以难熔高熵合金为主 。其在动态载荷
# 下变形时不易产生孪晶 ，位错运动剧烈 ，塞积严重以
# 及导热性较差 ，容易产生绝热剪切效应 。研究人员...
# 17 | ../PDF\Wang …等 - 2024 - Research progress in dynamic mechanical behavior of high-entropy alloys.pdf | 0 | 798 | of Military Sciences ，Beijing 100071，China；3 Ocean College ，
# Zhejiang University ，Zhoushan 316021，Zh...
# 18 | ../PDF\Zhao …等 - 2022 - Research Progress in High-Entropy Alloy Bond Coat Material for Thermal Barrier Coatings.pdf | 2 | 791 | 4期 赵晓峰等 ：热障涂层高熵合金粘结层材料研究进展
# 分析，通过粘结层的高熵化设计 ，有望解决传统
# MCrAlY粘结层中存在的抗氧化性能差 、粘结层 -基
# 体互扩散以及高温强度不足 3个关键问题 ，从...
# 19 | ../PDF\Ma …等 - 2024 - Microstructure and Properties of Fe2-xCrMnAlxCu High Entropy Alloy.pdf | 0 | 788 | 组研究了 Al元素含量对 FeCrMnAl
# xCu高熵合金组织
# 和性能的影响[10]，同时也研究了 Fe元素含量变化对
# FexCrMnAlCu 基高熵合金组织和性能的影响[11]，结合
# 两者的研究可知...
# 2025-04-12 16:00:49,587 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 🤖 回答：要确定哪一组合金性能最好，我们需要明确评价标准，例如强度、韧性、耐腐蚀性等。以下是一些高熵合金的性能比较：
#
# | 合金类型 | 屈服强度 (MPa) | 抗拉强度 (MPa) | 延伸率 (%) | 其他特性 |
# |----------|-----------------|-----------------|------------|----------|
# | FeCoNiCrMn [6] | 563 MPa | 未提及 | 52% | 单相 fcc 结构，良好的塑性 |
# | TiZrVNb [1] | 高强低韧（具体数值未提及） | 未提及 | 未提及 | V2Zr 相析出强化，但破坏了韧性 |
# | AlCoCrFeNi2.1 [14] | 屈服强度未提及，抗拉强度超过1 GPa, 延伸率39%[12]，700 MPa (77 K)[4]，断裂强度超过1 GPa[4], 延伸率9%[4]| 优异的低温性能，共晶组织由 B2 和 fcc 相组成 |
#
# 从上表可以看出，不同合金在不同条件下表现出不同的优异性能。例如：
# - FeCoNiCrMn 合金具有良好的延展性和单相结构。
# - AlCoCrFeNi2.1 共晶高熵合金在低温下表现出优异的力学性能，并且其共晶组织提供了良好的综合力学性能。
#
# 因此，“最好”的定义取决于应用场景和所需特定属性。如果需要更详细的信息或针对特定应用场景，请提供更多细节以便进一步分析。
#
# ⏱️ 總耗時: 12.69 秒
#
# ---- 最近一次檢索的詳細信息 ----
# 📊 檢索統計:
# - 共檢索到 20 個文檔片段
# - 來自 12 個不同來源
# - 檢索耗時: 1.51 秒
#
# 📑 檢索文檔詳情:
# 索引 | 來源 | 頁碼 | 內容長度 | 內容預覽
# ----- | ----- | ----- | ----- | -----
# 0 | ../PDF\Xu …等 - 2022 - Toughening Pathways and Regulatory Mechanisms of Refractory High-Entropy Alloys.pdf | 4 | 759 | 力学性能 。Huang等[36]设计的 TaxHfZrTi双相难熔高
# 熵合金表现出较大的延伸率 ，由于 TRIP效应诱导
# hcp相形成，合金中 bcc相和 hcp相之间的动态应变 -
# 应力分配产生强烈...
# 1 | ../PDF\Zhao …等 - 2024 - Research Status of Phase Transformation Behavior of High Entropy Shape Memory Alloys.pdf | 3 | 668 | 当Cr含量为 10%（质量分数）时合金性能较好。朱琳[44]
# 研究了 AlCoCrFeNi x在热处理过程中的相变行为，如图 3
# 所示。当 x=0.4，0.8时，在 600 ℃发生单一的可逆相变。
# 当...
# 2 | ../PDF\Xu …等 - 2022 - Toughening Pathways and Regulatory Mechanisms of Refractory High-Entropy Alloys.pdf | 7 | 410 | 开发具有高强高韧的金属材料一直是材料领域
# 的研究热门 。传统金属材料常采用细晶强化 、固溶
# 强化、第二相强化和相变强化等强韧化手段达到改
# 善力学性能的目的 ，就目前研究而言 ，只有绝大部分
# 3d过渡金...
# 3 | ../PDF\Liu …等 - 2023 - Progress of Cryogenic Deformation and Strengthening-Toughening Mechanisms of High-Entropy Alloys.pdf | 9 | 799 | 59 卷 金 属 学 报
# 超高强度水平 ，同时还保持 53%的优异延伸率 ，如
# 图10b[91]所示。
# 另外，结合析出强化和相转变行为的耦合强韧
# 化机制也被应用于提升高熵合金的性能 。2020年，
# D...
# 4 | ../PDF\Xu …等 - 2022 - Toughening Pathways and Regulatory Mechanisms of Refractory High-Entropy Alloys.pdf | 7 | 791 | Ti2Al4不仅抗拉强度显著提高 ，稳态蠕变速率也降低
# 了约 2个数量级 ，表明其高温性能显著改善[99]。目
# 前，难熔高熵合金的高温蠕变性能尚未见报道 。
# 3难熔高熵合金的力学性能调控
# 难熔高熵合金...
# 5 | ../PDF\Lu …等 - 2018 - Deformation Behavior and Toughening of High-Entropy Alloys.pdf | 1 | 778 | 将合金的性能达到最优化 。已开发研究的合金体系
# 大体可以分为 2大类：一类是以 Al及第 IV周期元素
# Fe、Co、Ni、Cr、Cu、Mn、Ti为主的合金系 ；一类是以
# 难熔金属元素 Mo、Ti、V、...
# 6 | ../PDF\Huang …等 - 2021 - Preparation, structures and properties of tungsten-containing refractory high entropy alloys.pdf | 1 | 773 | 1   引　言
# 未来核聚变反应堆第一面向等离子材料所面
# 临的工况条件是: 工作温度为570—1270 K, 热负
# 荷为2—20 MW/m2, 中子通量为每个原子数个位
# 移的累积(dpa)/年[1 −5...
# 7 | ../PDF\Yang …等 - 2020 - Microscopic phase-field simulation for precipitation process of Ni60Al20V20 medium entropy alloy.pdf | 1 | 545 | 合金强度和延展性, Zhao等[10]对CoCrNi中熵合
# 金研究表明, 中熵合金经纳米L12结构  相沉淀强
# 化, 其屈服强度和抗拉强度分别提高70%和45%.
# 目前对中熵合金研究主要集中在制备方...
# 8 | ../PDF\Ma …等 - 2024 - Microstructure and Properties of Fe2-xCrMnAlxCu High Entropy Alloy.pdf | 0 | 782 | 晶组织均由 bcc相构成，且枝晶内部析出有序 bcc结构的 FeAl相。随着 Fe含量减少， Al含量的增加，其析出物含量
# 略微增加，使得 Fe2-xCrMnAl xCu高熵合金的硬度不断增加。当 x...
# 9 | ../PDF\Sun …等 - 2020 - Property tuning and additive manufacturing of refractory high-entropy alloys.pdf | 2 | 795 | 增材制
# 造成形和应用进行了展望
# 。
# １
#
# 难熔高熵合金的性能调控
# 高强度与良好的塑性一直是材料研发中的热点问
# 题
# ，
# 两者相对制约的关系使得大多数材料在强化时导
# 致塑性变形能力降低
# ，
# 因此实现材料...
# 10 | ../PDF\Wang …等 - 2025 - Revisiting the Development of Eutectic High-Entropy Alloys over the Past Decade (2014--2024)Design,.pdf | 5 | 781 | 变形量冷轧后进行等温退火 ，可获得具有等轴超细晶的两相组织 ，使AlCoCrFeNi2.1合金强度得以大幅度
# 提升[53,55]。而通过中温轧制能够调控出同时包含等轴
# 和层片组织的异质结构共晶高熵合金...
# 11 | ../PDF\Wu …等 - 2024 - Effect of AlCoCrFeNi High-Entropy Alloy on Microstructure and Mechanical Properties of Al-Si-Cu Allo.pdf | 8 | 760 | Wu Qingjie et al . / Rare Metal Materials and Engineering , 2024 , 53(11):3017 -3025
# Science & Techn...
# 12 | ../PDF\Liu …等 - 2023 - Progress of Cryogenic Deformation and Strengthening-Toughening Mechanisms of High-Entropy Alloys.pdf | 11 | 771 | 4.2 低温超高强度高熵合金的韧塑化机理
# 目前虽有少量 2 GPa高熵合金的研究报
# 道[42,48,91,103~106]，但大多数合金的低温屈服强度在
# 1.5 GPa以下，没有展现出超高强韧高熵合金...
# 13 | ../PDF\Lu …等 - 2018 - Deformation Behavior and Toughening of High-Entropy Alloys.pdf | 6 | 666 | 单相 bcc高熵合金具有较高的强度 ，但其塑性较低 ，
# 比如 TaHfZrTi 具有 1.5GPa的高拉伸强度 ，但其塑性
# 只有大约 4%[11]。另外，由于包含多种高浓度的元
# 素，高熵合金具有较差的...
# 14 | ../PDF\Wang …等 - 2025 - Revisiting the Development of Eutectic High-Entropy Alloys over the Past Decade (2014--2024)Design,.pdf | 6 | 765 | 环境下可以形成致密而稳定的 Fe-Cr-Al-O 氧化膜，
# 显著阻碍了液态 Pb-Bi向基体的扩散和溶解 。相比
# 于传统的铁素体 /马氏体钢和奥氏体不锈钢 ，该合金
# 在高温 Pb-Bi环境中更为稳定 ...
# 15 | ../PDF\Huang …等 - 2021 - Preparation, structures and properties of tungsten-containing refractory high entropy alloys.pdf | 6 | 778 | 采用真空电弧熔炼法制备了该合金, 并对其性能进
# 行了探讨. 研究发现, 在600—800 °C温度下, 抗
# 压屈服强度超过1000 MPa, 具有优异的耐热抗软
# 化性能.
# 众所周知[86 −88], ...
# 16 | ../PDF\Wang …等 - 2024 - Research progress in dynamic mechanical behavior of high-entropy alloys.pdf | 8 | 777 | BCC结构高熵合金强度较高 ，但塑性和应变硬化
# 能力较差 ，主要以难熔高熵合金为主 。其在动态载荷
# 下变形时不易产生孪晶 ，位错运动剧烈 ，塞积严重以
# 及导热性较差 ，容易产生绝热剪切效应 。研究人员...
# 17 | ../PDF\Wang …等 - 2024 - Research progress in dynamic mechanical behavior of high-entropy alloys.pdf | 0 | 798 | of Military Sciences ，Beijing 100071，China；3 Ocean College ，
# Zhejiang University ，Zhoushan 316021，Zh...
# 18 | ../PDF\Zhao …等 - 2022 - Research Progress in High-Entropy Alloy Bond Coat Material for Thermal Barrier Coatings.pdf | 2 | 791 | 4期 赵晓峰等 ：热障涂层高熵合金粘结层材料研究进展
# 分析，通过粘结层的高熵化设计 ，有望解决传统
# MCrAlY粘结层中存在的抗氧化性能差 、粘结层 -基
# 体互扩散以及高温强度不足 3个关键问题 ，从...
# 19 | ../PDF\Ma …等 - 2024 - Microstructure and Properties of Fe2-xCrMnAlxCu High Entropy Alloy.pdf | 0 | 788 | 组研究了 Al元素含量对 FeCrMnAl
# xCu高熵合金组织
# 和性能的影响[10]，同时也研究了 Fe元素含量变化对
# FexCrMnAlCu 基高熵合金组织和性能的影响[11]，结合
# 两者的研究可知...
